# %% [markdown]
# Misc imports

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
import matplotlib.pyplot as plt
from six.moves.cPickle import load
import cPickle
import numpy as np

from snorkel import SnorkelSession
from snorkel.parser import XMLMultiDocPreprocessor, CorpusParser
from snorkel.parser.spacy_parser import Spacy
from snorkel.parser.corenlp import StanfordCoreNLPServer
from snorkel.models import Document, Sentence, Candidate, candidate_subclass
from snorkel.candidates import Ngrams, CandidateExtractor
from snorkel.viewer import SentenceNgramViewer
from snorkel.annotations import LabelAnnotator, load_gold_labels, FeatureAnnotator, save_marginals, load_marginals
from snorkel.learning import SparseLogisticRegression, GenerativeModel, RandomSearch
from snorkel.learning.structure import DependencySelector
from snorkel.learning.utils import MentionScorer
# from snorkel.contrib.rnn import reRNN

import matchers
import LF
from candidate_adjective_fixer import *
from load_external_annotations_new import load_external_labels

session = SnorkelSession()

BiomarkerLevelUnit = candidate_subclass('BiomarkerLevelUnit', ['biomarker', 'level', 'unit'])
os.environ['SNORKELDB']= 'sqlite:///' + os.getcwd() + os.sep + 'cameron.db'
# Out:
# /Users/gmachiraju/py2_kernel/lib/python2.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 162 of the file /usr/local/Cellar/python/2.7.9/Frameworks/Python.framework/Versions/2.7/lib/python2.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %% [markdown]
# Helper functions

# %%
#------------------
# Helper Functions
#------------------

def grabCandidates(extractor, schema):
    # Candidate Counts
    for k, sents in enumerate([train_sents, dev_sents, test_sents]):
        extractor.apply(sents, split=k, clear=False)
        print "Number of candidates: ", session.query(schema).filter(schema.split == k).count()
        session.commit()
        
    train_cands = session.query(schema).filter(
        schema.split == 0).all()
    dev_cands = session.query(schema).filter(
        schema.split == 1).all()
    test_cands = session.query(schema).filter(
        schema.split == 2).all()

    return [train_cands, dev_cands, test_cands]

# %%
#-----------------------
# Setup & Preprocessing
#-----------------------

# Instantiate the Session
session = SnorkelSession()

# Doc Preprocessing
file_path = 'articles/training.xml'
train_preprocessor = XMLMultiDocPreprocessor(
    path=file_path,
    doc='.//article',
    text='.//front/article-meta/abstract/p/text()',
    id='.//front/article-meta/article-id/text()'
)

file_path = 'articles/development.xml'
dev_preprocessor = XMLMultiDocPreprocessor(
    path=file_path,
    doc='.//document',
    text='.//passage/text/text()',
    id='.//id/text()'
)

file_path = 'articles/testcorpus.xml'
test_preprocessor = XMLMultiDocPreprocessor(
    path=file_path,
    doc='.//document',
    text='.//passage/text/text()',
    id='.//id/text()'
)

# Parsing
# corenlp_server = StanfordCoreNLPServer(version="3.6.0", num_threads=4, port=12348)
# corpus_parser = CorpusParser(corenlp_server, parser=Spacy())
corpus_parser = CorpusParser(parser=Spacy())
# corpus_parser = CorpusParser()

# Note: Parallelism can be run with a Postgres DBMS, but not SQLite
corpus_parser.apply(list(train_preprocessor))
corpus_parser.apply(list(dev_preprocessor), clear=False)
corpus_parser.apply(list(test_preprocessor), clear=False)
# Out:
# Clearing existing...
# Running UDF...
# [========================================] 100%
#
# Running UDF...
# [========================================] 100%
#
# Running UDF...
# [========================================] 100%

# %%
# Retrieving Stable IDs for each of the candidate sentences
with open('articles/doc_ids.pkl', 'rb') as f:
    train_ids, dev_ids, test_ids = load(f)

train_ids, dev_ids, test_ids = set(train_ids), set(dev_ids), set(test_ids)
train_sents, dev_sents, test_sents = set(), set(), set()
docs = session.query(Document).order_by(Document.name).all()


# Assigning each sentence to {train,dev,test}-set based on Stable ID
for i, doc in enumerate(docs):
    for s in doc.sentences:
        if doc.name in train_ids:
            train_sents.add(s)
        elif doc.name in dev_ids:
            dev_sents.add(s)
        elif doc.name in test_ids:
            test_sents.add(s)
        else:
            raise Exception(
                'ID <{0}> not found in any id set'.format(doc.name))

# %%
#----------------------
# Candidate Extraction
#----------------------

# Defining the Candidate Schemas
# BiomarkerCondition = candidate_subclass('BiomarkerCondition', ['biomarker', 'condition'])

# BiomarkerDrug = candidate_subclass('BiomarkerDrug', ['biomarker', 'drug'])
# BiomarkerMedium = candidate_subclass('BiomarkerMedium', ['biomarker', 'medium'])
# BiomarkerType = candidate_subclass('BiomarkerType', ['biomarker', 'typ3'])
# # BiomarkerLevelUnit = candidate_subclass('BiomarkerLevelUnit', ['biomarker', 'level', 'unit'])
#can eventually add MEASUREMENT and COHORT SIZE among other entities

# N-grams: the probabilistic search space of our entities
biomarker_ngrams = Ngrams(n_max=1)
# condition_ngrams = Ngrams(n_max=7)
# drug_ngrams = Ngrams(n_max=5)
# medium_ngrams = Ngrams(n_max=5)
# type_ngrams = Ngrams(n_max=5)  # <--- Q: should we cut these down?
level_ngrams = Ngrams(n_max=1)
unit_ngrams = Ngrams(n_max=1)

# Construct our Matchers
bMatcher = matchers.getBiomarkerMatcher()
# cMatcher = matchers.getConditionMatcher()
# dMatcher = matchers.getDrugMatcher()
# mMatcher = matchers.getMediumMatcher()
# tMatcher = matchers.getTypeMatcher()
lMatcher = matchers.getLevelMatcher()
uMatcher = matchers.getUnitMatcher()

# Building the CandidateExtractors
# candidate_extractor_BC = CandidateExtractor(BiomarkerCondition, [biomarker_ngrams, condition_ngrams], [bMatcher, cMatcher])
# candidate_extractor_BD = CandidateExtractor(BiomarkerDrug, [biomarker_ngrams, drug_ngrams], [bMatcher, dMatcher])
# candidate_extractor_BM = CandidateExtractor(BiomarkerMedium, [biomarker_ngrams, medium_ngrams], [bMatcher, mMatcher])
# candidate_extractor_BT = CandidateExtractor(BiomarkerType, [biomarker_ngrams, type_ngrams], [bMatcher, tMatcher])
candidate_extractor_BLU = CandidateExtractor(BiomarkerLevelUnit, [biomarker_ngrams, level_ngrams, unit_ngrams], [bMatcher, lMatcher, uMatcher])

# List of Candidate Sets for each relation type: [train, dev, test]
# cands_BC = grabCandidates(candidate_extractor_BC, BiomarkerCondition)
# cands_BD = grabCandidates(candidate_extractor_BD, BiomarkerDrug)
# cands_BM = grabCandidates(candidate_extractor_BM, BiomarkerMedium)
# cands_BT = grabCandidates(candidate_extractor_BT, BiomarkerType)
cands_BLU = grabCandidates(candidate_extractor_BLU, BiomarkerLevelUnit)
# Out:
# Running UDF...
# [========================================] 100%
#
# Number of candidates:  762
# Running UDF...
# [========================================] 100%
#
# Number of candidates:  951
# Running UDF...
# [========================================] 100%
#
# Number of candidates:  6

# %%
train_cands = session.query(BiomarkerLevelUnit).filter(BiomarkerLevelUnit.split == 0).order_by(BiomarkerLevelUnit.id).all()
dev_cands   = session.query(BiomarkerLevelUnit).filter(BiomarkerLevelUnit.split == 1).order_by(BiomarkerLevelUnit.id).all()
test_cands  = session.query(BiomarkerLevelUnit).filter(BiomarkerLevelUnit.split == 2).order_by(BiomarkerLevelUnit.id).all()

# %%
for cand in train_cands:
    print cand
# Out:
# BiomarkerLevelUnit(Span("UPT", sentence=12728, chars=[30,32], words=[6,6]), Span("116", sentence=12728, chars=[103,105], words=[25,25]), Span("mL", sentence=12728, chars=[171,172], words=[42,42]))
# BiomarkerLevelUnit(Span("UPT", sentence=12728, chars=[30,32], words=[6,6]), Span("116", sentence=12728, chars=[103,105], words=[25,25]), Span("ng", sentence=12728, chars=[107,108], words=[26,26]))
# BiomarkerLevelUnit(Span("UPT", sentence=12728, chars=[30,32], words=[6,6]), Span("116", sentence=12728, chars=[103,105], words=[25,25]), Span("ng", sentence=12728, chars=[168,169], words=[40,40]))
# BiomarkerLevelUnit(Span("UPT", sentence=12728, chars=[30,32], words=[6,6]), Span("150", sentence=12728, chars=[164,166], words=[39,39]), Span("mL", sentence=12728, chars=[171,172], words=[42,42]))
# BiomarkerLevelUnit(Span("UPT", sentence=12728, chars=[30,32], words=[6,6]), Span("150", sentence=12728, chars=[164,166], words=[39,39]), Span("ng", sentence=12728, chars=[107,108], words=[26,26]))
# BiomarkerLevelUnit(Span("UPT", sentence=12728, chars=[30,32], words=[6,6]), Span("150", sentence=12728, chars=[164,166], words=[39,39]), Span("ng", sentence=12728, chars=[168,169], words=[40,40]))
# BiomarkerLevelUnit(Span("CFU", sentence=6430, chars=[127,129], words=[27,27]), Span("10", sentence=6430, chars=[123,124], words=[25,25]), Span("fg", sentence=6430, chars=[99,100], words=[19,19]))
# BiomarkerLevelUnit(Span("CFU", sentence=6430, chars=[127,129], words=[27,27]), Span("10", sentence=6430, chars=[123,124], words=[25,25]), Span("ml", sentence=6430, chars=[131,132], words=[29,29]))
# BiomarkerLevelUnit(Span("CFU", sentence=6430, chars=[127,129], words=[27,27]), Span("160", sentence=6430, chars=[95,97], words=[18,18]), Span("fg", sentence=6430, chars=[99,100], words=[19,19]))
# BiomarkerLevelUnit(Span("CFU", sentence=6430, chars=[127,129], words=[27,27]), Span("160", sentence=6430, chars=[95,97], words=[18,18]), Span("ml", sentence=6430, chars=[131,132], words=[29,29]))
# BiomarkerLevelUnit(Span("CFU", sentence=6430, chars=[127,129], words=[27,27]), Span("25", sentence=6430, chars=[157,158], words=[34,34]), Span("fg", sentence=6430, chars=[99,100], words=[19,19]))
# BiomarkerLevelUnit(Span("CFU", sentence=6430, chars=[127,129], words=[27,27]), Span("25", sentence=6430, chars=[157,158], words=[34,34]), Span("ml", sentence=6430, chars=[131,132], words=[29,29]))
# BiomarkerLevelUnit(Span("CFU", sentence=6430, chars=[127,129], words=[27,27]), Span("2.2", sentence=6430, chars=[117,119], words=[23,23]), Span("fg", sentence=6430, chars=[99,100], words=[19,19]))
# BiomarkerLevelUnit(Span("CFU", sentence=6430, chars=[127,129], words=[27,27]), Span("2.2", sentence=6430, chars=[117,119], words=[23,23]), Span("ml", sentence=6430, chars=[131,132], words=[29,29]))
# BiomarkerLevelUnit(Span("DNA", sentence=6430, chars=[110,112], words=[21,21]), Span("10", sentence=6430, chars=[123,124], words=[25,25]), Span("fg", sentence=6430, chars=[99,100], words=[19,19]))
# BiomarkerLevelUnit(Span("DNA", sentence=6430, chars=[110,112], words=[21,21]), Span("10", sentence=6430, chars=[123,124], words=[25,25]), Span("ml", sentence=6430, chars=[131,132], words=[29,29]))
# BiomarkerLevelUnit(Span("DNA", sentence=6430, chars=[110,112], words=[21,21]), Span("160", sentence=6430, chars=[95,97], words=[18,18]), Span("fg", sentence=6430, chars=[99,100], words=[19,19]))
# BiomarkerLevelUnit(Span("DNA", sentence=6430, chars=[110,112], words=[21,21]), Span("160", sentence=6430, chars=[95,97], words=[18,18]), Span("ml", sentence=6430, chars=[131,132], words=[29,29]))
# BiomarkerLevelUnit(Span("DNA", sentence=6430, chars=[110,112], words=[21,21]), Span("25", sentence=6430, chars=[157,158], words=[34,34]), Span("fg", sentence=6430, chars=[99,100], words=[19,19]))
# BiomarkerLevelUnit(Span("DNA", sentence=6430, chars=[110,112], words=[21,21]), Span("25", sentence=6430, chars=[157,158], words=[34,34]), Span("ml", sentence=6430, chars=[131,132], words=[29,29]))
# BiomarkerLevelUnit(Span("DNA", sentence=6430, chars=[110,112], words=[21,21]), Span("2.2", sentence=6430, chars=[117,119], words=[23,23]), Span("fg", sentence=6430, chars=[99,100], words=[19,19]))
# BiomarkerLevelUnit(Span("DNA", sentence=6430, chars=[110,112], words=[21,21]), Span("2.2", sentence=6430, chars=[117,119], words=[23,23]), Span("ml", sentence=6430, chars=[131,132], words=[29,29]))
# BiomarkerLevelUnit(Span("CI", sentence=2993, chars=[123,124], words=[26,26]), Span("1.49", sentence=2993, chars=[167,170], words=[38,38]), Span("TG", sentence=2993, chars=[88,89], words=[17,17]))
# BiomarkerLevelUnit(Span("CI", sentence=2993, chars=[123,124], words=[26,26]), Span("0.010", sentence=2993, chars=[143,147], words=[32,32]), Span("TG", sentence=2993, chars=[88,89], words=[17,17]))
# BiomarkerLevelUnit(Span("CI", sentence=2993, chars=[123,124], words=[26,26]), Span("1.51", sentence=2993, chars=[113,116], words=[23,23]), Span("TG", sentence=2993, chars=[88,89], words=[17,17]))
# BiomarkerLevelUnit(Span("CI", sentence=2993, chars=[123,124], words=[26,26]), Span("0.008", sentence=2993, chars=[197,201], words=[47,47]), Span("TG", sentence=2993, chars=[88,89], words=[17,17]))
# BiomarkerLevelUnit(Span("TG", sentence=2993, chars=[88,89], words=[17,17]), Span("1.49", sentence=2993, chars=[167,170], words=[38,38]), Span("TG", sentence=2993, chars=[88,89], words=[17,17]))
# BiomarkerLevelUnit(Span("TG", sentence=2993, chars=[88,89], words=[17,17]), Span("0.010", sentence=2993, chars=[143,147], words=[32,32]), Span("TG", sentence=2993, chars=[88,89], words=[17,17]))
# BiomarkerLevelUnit(Span("TG", sentence=2993, chars=[88,89], words=[17,17]), Span("1.51", sentence=2993, chars=[113,116], words=[23,23]), Span("TG", sentence=2993, chars=[88,89], words=[17,17]))
# BiomarkerLevelUnit(Span("TG", sentence=2993, chars=[88,89], words=[17,17]), Span("0.008", sentence=2993, chars=[197,201], words=[47,47]), Span("TG", sentence=2993, chars=[88,89], words=[17,17]))
# BiomarkerLevelUnit(Span("HBV", sentence=2993, chars=[232,234], words=[54,54]), Span("1.49", sentence=2993, chars=[167,170], words=[38,38]), Span("TG", sentence=2993, chars=[88,89], words=[17,17]))
# BiomarkerLevelUnit(Span("HBV", sentence=2993, chars=[232,234], words=[54,54]), Span("0.010", sentence=2993, chars=[143,147], words=[32,32]), Span("TG", sentence=2993, chars=[88,89], words=[17,17]))
# BiomarkerLevelUnit(Span("HBV", sentence=2993, chars=[232,234], words=[54,54]), Span("1.51", sentence=2993, chars=[113,116], words=[23,23]), Span("TG", sentence=2993, chars=[88,89], words=[17,17]))
# BiomarkerLevelUnit(Span("HBV", sentence=2993, chars=[232,234], words=[54,54]), Span("0.008", sentence=2993, chars=[197,201], words=[47,47]), Span("TG", sentence=2993, chars=[88,89], words=[17,17]))
# BiomarkerLevelUnit(Span("CI", sentence=2993, chars=[177,178], words=[41,41]), Span("1.49", sentence=2993, chars=[167,170], words=[38,38]), Span("TG", sentence=2993, chars=[88,89], words=[17,17]))
# BiomarkerLevelUnit(Span("CI", sentence=2993, chars=[177,178], words=[41,41]), Span("0.010", sentence=2993, chars=[143,147], words=[32,32]), Span("TG", sentence=2993, chars=[88,89], words=[17,17]))
# BiomarkerLevelUnit(Span("CI", sentence=2993, chars=[177,178], words=[41,41]), Span("1.51", sentence=2993, chars=[113,116], words=[23,23]), Span("TG", sentence=2993, chars=[88,89], words=[17,17]))
# BiomarkerLevelUnit(Span("CI", sentence=2993, chars=[177,178], words=[41,41]), Span("0.008", sentence=2993, chars=[197,201], words=[47,47]), Span("TG", sentence=2993, chars=[88,89], words=[17,17]))
# BiomarkerLevelUnit(Span("HCC", sentence=2993, chars=[244,246], words=[57,57]), Span("1.49", sentence=2993, chars=[167,170], words=[38,38]), Span("TG", sentence=2993, chars=[88,89], words=[17,17]))
# BiomarkerLevelUnit(Span("HCC", sentence=2993, chars=[244,246], words=[57,57]), Span("0.010", sentence=2993, chars=[143,147], words=[32,32]), Span("TG", sentence=2993, chars=[88,89], words=[17,17]))
# BiomarkerLevelUnit(Span("HCC", sentence=2993, chars=[244,246], words=[57,57]), Span("1.51", sentence=2993, chars=[113,116], words=[23,23]), Span("TG", sentence=2993, chars=[88,89], words=[17,17]))
# BiomarkerLevelUnit(Span("HCC", sentence=2993, chars=[244,246], words=[57,57]), Span("0.008", sentence=2993, chars=[197,201], words=[47,47]), Span("TG", sentence=2993, chars=[88,89], words=[17,17]))
# BiomarkerLevelUnit(Span("CI", sentence=4954, chars=[122,123], words=[26,26]), Span("1.79", sentence=4954, chars=[112,115], words=[23,23]), Span("mg", sentence=4954, chars=[25,26], words=[6,6]))
# BiomarkerLevelUnit(Span("CI", sentence=4954, chars=[122,123], words=[26,26]), Span("1.79", sentence=4954, chars=[112,115], words=[23,23]), Span("dL", sentence=4954, chars=[28,29], words=[8,8]))
# BiomarkerLevelUnit(Span("CI", sentence=4954, chars=[122,123], words=[26,26]), Span("3.03", sentence=4954, chars=[134,137], words=[30,30]), Span("mg", sentence=4954, chars=[25,26], words=[6,6]))
# BiomarkerLevelUnit(Span("CI", sentence=4954, chars=[122,123], words=[26,26]), Span("3.03", sentence=4954, chars=[134,137], words=[30,30]), Span("dL", sentence=4954, chars=[28,29], words=[8,8]))
# BiomarkerLevelUnit(Span("CI", sentence=4954, chars=[122,123], words=[26,26]), Span("4", sentence=4954, chars=[23,23], words=[4,4]), Span("mg", sentence=4954, chars=[25,26], words=[6,6]))
# BiomarkerLevelUnit(Span("CI", sentence=4954, chars=[122,123], words=[26,26]), Span("4", sentence=4954, chars=[23,23], words=[4,4]), Span("dL", sentence=4954, chars=[28,29], words=[8,8]))
# BiomarkerLevelUnit(Span("CI", sentence=4954, chars=[122,123], words=[26,26]), Span("1.06", sentence=4954, chars=[126,129], words=[28,28]), Span("mg", sentence=4954, chars=[25,26], words=[6,6]))
# BiomarkerLevelUnit(Span("CI", sentence=4954, chars=[122,123], words=[26,26]), Span("1.06", sentence=4954, chars=[126,129], words=[28,28]), Span("dL", sentence=4954, chars=[28,29], words=[8,8]))
# BiomarkerLevelUnit(Span("CI", sentence=4954, chars=[122,123], words=[26,26]), Span("0.03", sentence=4954, chars=[144,147], words=[35,35]), Span("mg", sentence=4954, chars=[25,26], words=[6,6]))
# BiomarkerLevelUnit(Span("CI", sentence=4954, chars=[122,123], words=[26,26]), Span("0.03", sentence=4954, chars=[144,147], words=[35,35]), Span("dL", sentence=4954, chars=[28,29], words=[8,8]))
# BiomarkerLevelUnit(Span("HR", sentence=4954, chars=[108,109], words=[21,21]), Span("1.79", sentence=4954, chars=[112,115], words=[23,23]), Span("mg", sentence=4954, chars=[25,26], words=[6,6]))
# BiomarkerLevelUnit(Span("HR", sentence=4954, chars=[108,109], words=[21,21]), Span("1.79", sentence=4954, chars=[112,115], words=[23,23]), Span("dL", sentence=4954, chars=[28,29], words=[8,8]))
# BiomarkerLevelUnit(Span("HR", sentence=4954, chars=[108,109], words=[21,21]), Span("3.03", sentence=4954, chars=[134,137], words=[30,30]), Span("mg", sentence=4954, chars=[25,26], words=[6,6]))
# BiomarkerLevelUnit(Span("HR", sentence=4954, chars=[108,109], words=[21,21]), Span("3.03", sentence=4954, chars=[134,137], words=[30,30]), Span("dL", sentence=4954, chars=[28,29], words=[8,8]))
# BiomarkerLevelUnit(Span("HR", sentence=4954, chars=[108,109], words=[21,21]), Span("4", sentence=4954, chars=[23,23], words=[4,4]), Span("mg", sentence=4954, chars=[25,26], words=[6,6]))
# BiomarkerLevelUnit(Span("HR", sentence=4954, chars=[108,109], words=[21,21]), Span("4", sentence=4954, chars=[23,23], words=[4,4]), Span("dL", sentence=4954, chars=[28,29], words=[8,8]))
# BiomarkerLevelUnit(Span("HR", sentence=4954, chars=[108,109], words=[21,21]), Span("1.06", sentence=4954, chars=[126,129], words=[28,28]), Span("mg", sentence=4954, chars=[25,26], words=[6,6]))
# BiomarkerLevelUnit(Span("HR", sentence=4954, chars=[108,109], words=[21,21]), Span("1.06", sentence=4954, chars=[126,129], words=[28,28]), Span("dL", sentence=4954, chars=[28,29], words=[8,8]))
# BiomarkerLevelUnit(Span("HR", sentence=4954, chars=[108,109], words=[21,21]), Span("0.03", sentence=4954, chars=[144,147], words=[35,35]), Span("mg", sentence=4954, chars=[25,26], words=[6,6]))
# BiomarkerLevelUnit(Span("HR", sentence=4954, chars=[108,109], words=[21,21]), Span("0.03", sentence=4954, chars=[144,147], words=[35,35]), Span("dL", sentence=4954, chars=[28,29], words=[8,8]))
# BiomarkerLevelUnit(Span("ECM", sentence=12913, chars=[4,6], words=[1,1]), Span("72", sentence=12913, chars=[283,284], words=[55,55]), Span("mg", sentence=12913, chars=[27,28], words=[5,5]))
# BiomarkerLevelUnit(Span("ECM", sentence=12913, chars=[4,6], words=[1,1]), Span("72", sentence=12913, chars=[283,284], words=[55,55]), Span("mL", sentence=12913, chars=[30,31], words=[7,7]))
# BiomarkerLevelUnit(Span("ECM", sentence=12913, chars=[4,6], words=[1,1]), Span("3.2", sentence=12913, chars=[23,25], words=[4,4]), Span("mg", sentence=12913, chars=[27,28], words=[5,5]))
# BiomarkerLevelUnit(Span("ECM", sentence=12913, chars=[4,6], words=[1,1]), Span("3.2", sentence=12913, chars=[23,25], words=[4,4]), Span("mL", sentence=12913, chars=[30,31], words=[7,7]))
# BiomarkerLevelUnit(Span("ECM", sentence=12913, chars=[4,6], words=[1,1]), Span("24", sentence=12913, chars=[137,138], words=[29,29]), Span("mg", sentence=12913, chars=[27,28], words=[5,5]))
# BiomarkerLevelUnit(Span("ECM", sentence=12913, chars=[4,6], words=[1,1]), Span("24", sentence=12913, chars=[137,138], words=[29,29]), Span("mL", sentence=12913, chars=[30,31], words=[7,7]))
# BiomarkerLevelUnit(Span("A549", sentence=12913, chars=[88,91], words=[19,19]), Span("72", sentence=12913, chars=[283,284], words=[55,55]), Span("mg", sentence=12913, chars=[27,28], words=[5,5]))
# BiomarkerLevelUnit(Span("A549", sentence=12913, chars=[88,91], words=[19,19]), Span("72", sentence=12913, chars=[283,284], words=[55,55]), Span("mL", sentence=12913, chars=[30,31], words=[7,7]))
# BiomarkerLevelUnit(Span("A549", sentence=12913, chars=[88,91], words=[19,19]), Span("3.2", sentence=12913, chars=[23,25], words=[4,4]), Span("mg", sentence=12913, chars=[27,28], words=[5,5]))
# BiomarkerLevelUnit(Span("A549", sentence=12913, chars=[88,91], words=[19,19]), Span("3.2", sentence=12913, chars=[23,25], words=[4,4]), Span("mL", sentence=12913, chars=[30,31], words=[7,7]))
# BiomarkerLevelUnit(Span("A549", sentence=12913, chars=[88,91], words=[19,19]), Span("24", sentence=12913, chars=[137,138], words=[29,29]), Span("mg", sentence=12913, chars=[27,28], words=[5,5]))
# BiomarkerLevelUnit(Span("A549", sentence=12913, chars=[88,91], words=[19,19]), Span("24", sentence=12913, chars=[137,138], words=[29,29]), Span("mL", sentence=12913, chars=[30,31], words=[7,7]))
# BiomarkerLevelUnit(Span("HFB", sentence=1552, chars=[81,83], words=[18,18]), Span("10", sentence=1552, chars=[164,165], words=[36,36]), Span("mg", sentence=1552, chars=[111,112], words=[24,24]))
# BiomarkerLevelUnit(Span("HFB", sentence=1552, chars=[81,83], words=[18,18]), Span("80", sentence=1552, chars=[108,109], words=[23,23]), Span("mg", sentence=1552, chars=[111,112], words=[24,24]))
# BiomarkerLevelUnit(Span("AMI", sentence=4883, chars=[69,71], words=[16,16]), Span("129.45", sentence=4883, chars=[77,82], words=[18,18]), Span("ng", sentence=4883, chars=[84,85], words=[19,19]))
# BiomarkerLevelUnit(Span("CKD", sentence=4883, chars=[3,5], words=[1,1]), Span("129.45", sentence=4883, chars=[77,82], words=[18,18]), Span("ng", sentence=4883, chars=[84,85], words=[19,19]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[5,7], words=[2,2]), Span("129.45", sentence=4886, chars=[18,23], words=[6,6]), Span("ng", sentence=4886, chars=[25,26], words=[8,8]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[5,7], words=[2,2]), Span("129.45", sentence=4886, chars=[18,23], words=[6,6]), Span("ng", sentence=4886, chars=[53,54], words=[18,18]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[5,7], words=[2,2]), Span("129.45", sentence=4886, chars=[18,23], words=[6,6]), Span("ng", sentence=4886, chars=[84,85], words=[28,28]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[5,7], words=[2,2]), Span("5", sentence=4886, chars=[71,71], words=[24,24]), Span("ng", sentence=4886, chars=[25,26], words=[8,8]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[5,7], words=[2,2]), Span("5", sentence=4886, chars=[71,71], words=[24,24]), Span("ng", sentence=4886, chars=[53,54], words=[18,18]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[5,7], words=[2,2]), Span("5", sentence=4886, chars=[71,71], words=[24,24]), Span("ng", sentence=4886, chars=[84,85], words=[28,28]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[5,7], words=[2,2]), Span("4", sentence=4886, chars=[43,43], words=[14,14]), Span("ng", sentence=4886, chars=[25,26], words=[8,8]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[5,7], words=[2,2]), Span("4", sentence=4886, chars=[43,43], words=[14,14]), Span("ng", sentence=4886, chars=[53,54], words=[18,18]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[5,7], words=[2,2]), Span("4", sentence=4886, chars=[43,43], words=[14,14]), Span("ng", sentence=4886, chars=[84,85], words=[28,28]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[5,7], words=[2,2]), Span("3", sentence=4886, chars=[15,15], words=[4,4]), Span("ng", sentence=4886, chars=[25,26], words=[8,8]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[5,7], words=[2,2]), Span("3", sentence=4886, chars=[15,15], words=[4,4]), Span("ng", sentence=4886, chars=[53,54], words=[18,18]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[5,7], words=[2,2]), Span("3", sentence=4886, chars=[15,15], words=[4,4]), Span("ng", sentence=4886, chars=[84,85], words=[28,28]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[5,7], words=[2,2]), Span("149.35", sentence=4886, chars=[77,82], words=[26,26]), Span("ng", sentence=4886, chars=[25,26], words=[8,8]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[5,7], words=[2,2]), Span("149.35", sentence=4886, chars=[77,82], words=[26,26]), Span("ng", sentence=4886, chars=[53,54], words=[18,18]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[5,7], words=[2,2]), Span("149.35", sentence=4886, chars=[77,82], words=[26,26]), Span("ng", sentence=4886, chars=[84,85], words=[28,28]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[5,7], words=[2,2]), Span("105.50", sentence=4886, chars=[46,51], words=[16,16]), Span("ng", sentence=4886, chars=[25,26], words=[8,8]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[5,7], words=[2,2]), Span("105.50", sentence=4886, chars=[46,51], words=[16,16]), Span("ng", sentence=4886, chars=[53,54], words=[18,18]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[5,7], words=[2,2]), Span("105.50", sentence=4886, chars=[46,51], words=[16,16]), Span("ng", sentence=4886, chars=[84,85], words=[28,28]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[61,63], words=[22,22]), Span("129.45", sentence=4886, chars=[18,23], words=[6,6]), Span("ng", sentence=4886, chars=[25,26], words=[8,8]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[61,63], words=[22,22]), Span("129.45", sentence=4886, chars=[18,23], words=[6,6]), Span("ng", sentence=4886, chars=[53,54], words=[18,18]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[61,63], words=[22,22]), Span("129.45", sentence=4886, chars=[18,23], words=[6,6]), Span("ng", sentence=4886, chars=[84,85], words=[28,28]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[61,63], words=[22,22]), Span("5", sentence=4886, chars=[71,71], words=[24,24]), Span("ng", sentence=4886, chars=[25,26], words=[8,8]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[61,63], words=[22,22]), Span("5", sentence=4886, chars=[71,71], words=[24,24]), Span("ng", sentence=4886, chars=[53,54], words=[18,18]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[61,63], words=[22,22]), Span("5", sentence=4886, chars=[71,71], words=[24,24]), Span("ng", sentence=4886, chars=[84,85], words=[28,28]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[61,63], words=[22,22]), Span("4", sentence=4886, chars=[43,43], words=[14,14]), Span("ng", sentence=4886, chars=[25,26], words=[8,8]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[61,63], words=[22,22]), Span("4", sentence=4886, chars=[43,43], words=[14,14]), Span("ng", sentence=4886, chars=[53,54], words=[18,18]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[61,63], words=[22,22]), Span("4", sentence=4886, chars=[43,43], words=[14,14]), Span("ng", sentence=4886, chars=[84,85], words=[28,28]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[61,63], words=[22,22]), Span("3", sentence=4886, chars=[15,15], words=[4,4]), Span("ng", sentence=4886, chars=[25,26], words=[8,8]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[61,63], words=[22,22]), Span("3", sentence=4886, chars=[15,15], words=[4,4]), Span("ng", sentence=4886, chars=[53,54], words=[18,18]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[61,63], words=[22,22]), Span("3", sentence=4886, chars=[15,15], words=[4,4]), Span("ng", sentence=4886, chars=[84,85], words=[28,28]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[61,63], words=[22,22]), Span("149.35", sentence=4886, chars=[77,82], words=[26,26]), Span("ng", sentence=4886, chars=[25,26], words=[8,8]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[61,63], words=[22,22]), Span("149.35", sentence=4886, chars=[77,82], words=[26,26]), Span("ng", sentence=4886, chars=[53,54], words=[18,18]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[61,63], words=[22,22]), Span("149.35", sentence=4886, chars=[77,82], words=[26,26]), Span("ng", sentence=4886, chars=[84,85], words=[28,28]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[61,63], words=[22,22]), Span("105.50", sentence=4886, chars=[46,51], words=[16,16]), Span("ng", sentence=4886, chars=[25,26], words=[8,8]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[61,63], words=[22,22]), Span("105.50", sentence=4886, chars=[46,51], words=[16,16]), Span("ng", sentence=4886, chars=[53,54], words=[18,18]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[61,63], words=[22,22]), Span("105.50", sentence=4886, chars=[46,51], words=[16,16]), Span("ng", sentence=4886, chars=[84,85], words=[28,28]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[33,35], words=[12,12]), Span("129.45", sentence=4886, chars=[18,23], words=[6,6]), Span("ng", sentence=4886, chars=[25,26], words=[8,8]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[33,35], words=[12,12]), Span("129.45", sentence=4886, chars=[18,23], words=[6,6]), Span("ng", sentence=4886, chars=[53,54], words=[18,18]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[33,35], words=[12,12]), Span("129.45", sentence=4886, chars=[18,23], words=[6,6]), Span("ng", sentence=4886, chars=[84,85], words=[28,28]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[33,35], words=[12,12]), Span("5", sentence=4886, chars=[71,71], words=[24,24]), Span("ng", sentence=4886, chars=[25,26], words=[8,8]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[33,35], words=[12,12]), Span("5", sentence=4886, chars=[71,71], words=[24,24]), Span("ng", sentence=4886, chars=[53,54], words=[18,18]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[33,35], words=[12,12]), Span("5", sentence=4886, chars=[71,71], words=[24,24]), Span("ng", sentence=4886, chars=[84,85], words=[28,28]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[33,35], words=[12,12]), Span("4", sentence=4886, chars=[43,43], words=[14,14]), Span("ng", sentence=4886, chars=[25,26], words=[8,8]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[33,35], words=[12,12]), Span("4", sentence=4886, chars=[43,43], words=[14,14]), Span("ng", sentence=4886, chars=[53,54], words=[18,18]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[33,35], words=[12,12]), Span("4", sentence=4886, chars=[43,43], words=[14,14]), Span("ng", sentence=4886, chars=[84,85], words=[28,28]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[33,35], words=[12,12]), Span("3", sentence=4886, chars=[15,15], words=[4,4]), Span("ng", sentence=4886, chars=[25,26], words=[8,8]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[33,35], words=[12,12]), Span("3", sentence=4886, chars=[15,15], words=[4,4]), Span("ng", sentence=4886, chars=[53,54], words=[18,18]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[33,35], words=[12,12]), Span("3", sentence=4886, chars=[15,15], words=[4,4]), Span("ng", sentence=4886, chars=[84,85], words=[28,28]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[33,35], words=[12,12]), Span("149.35", sentence=4886, chars=[77,82], words=[26,26]), Span("ng", sentence=4886, chars=[25,26], words=[8,8]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[33,35], words=[12,12]), Span("149.35", sentence=4886, chars=[77,82], words=[26,26]), Span("ng", sentence=4886, chars=[53,54], words=[18,18]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[33,35], words=[12,12]), Span("149.35", sentence=4886, chars=[77,82], words=[26,26]), Span("ng", sentence=4886, chars=[84,85], words=[28,28]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[33,35], words=[12,12]), Span("105.50", sentence=4886, chars=[46,51], words=[16,16]), Span("ng", sentence=4886, chars=[25,26], words=[8,8]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[33,35], words=[12,12]), Span("105.50", sentence=4886, chars=[46,51], words=[16,16]), Span("ng", sentence=4886, chars=[53,54], words=[18,18]))
# BiomarkerLevelUnit(Span("CKD", sentence=4886, chars=[33,35], words=[12,12]), Span("105.50", sentence=4886, chars=[46,51], words=[16,16]), Span("ng", sentence=4886, chars=[84,85], words=[28,28]))
# BiomarkerLevelUnit(Span("IPF", sentence=6014, chars=[37,39], words=[6,6]), Span("0.05", sentence=6014, chars=[224,227], words=[50,50]), Span("mL", sentence=6014, chars=[153,154], words=[28,28]))
# BiomarkerLevelUnit(Span("IL-6", sentence=6014, chars=[205,208], words=[38,38]), Span("0.05", sentence=6014, chars=[224,227], words=[50,50]), Span("mL", sentence=6014, chars=[153,154], words=[28,28]))
# BiomarkerLevelUnit(Span("uPA", sentence=6014, chars=[197,199], words=[36,36]), Span("0.05", sentence=6014, chars=[224,227], words=[50,50]), Span("mL", sentence=6014, chars=[153,154], words=[28,28]))
# BiomarkerLevelUnit(Span("LLDT8", sentence=4524, chars=[37,41], words=[6,6]), Span("125", sentence=4524, chars=[111,113], words=[17,17]), Span("kg", sentence=4524, chars=[205,206], words=[38,38]))
# BiomarkerLevelUnit(Span("LLDT8", sentence=4524, chars=[37,41], words=[6,6]), Span("125", sentence=4524, chars=[111,113], words=[17,17]), Span("kg", sentence=4524, chars=[118,119], words=[20,20]))
# BiomarkerLevelUnit(Span("LLDT8", sentence=4524, chars=[37,41], words=[6,6]), Span("31.25", sentence=4524, chars=[196,200], words=[35,35]), Span("kg", sentence=4524, chars=[205,206], words=[38,38]))
# BiomarkerLevelUnit(Span("LLDT8", sentence=4524, chars=[37,41], words=[6,6]), Span("31.25", sentence=4524, chars=[196,200], words=[35,35]), Span("kg", sentence=4524, chars=[118,119], words=[20,20]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[85,88], words=[15,15]), Span("150", sentence=3440, chars=[125,127], words=[26,26]), Span("pg", sentence=3440, chars=[129,130], words=[27,27]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[85,88], words=[15,15]), Span("150", sentence=3440, chars=[125,127], words=[26,26]), Span("mL", sentence=3440, chars=[175,176], words=[41,41]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[85,88], words=[15,15]), Span("150", sentence=3440, chars=[125,127], words=[26,26]), Span("pg", sentence=3440, chars=[172,173], words=[39,39]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[85,88], words=[15,15]), Span("150", sentence=3440, chars=[125,127], words=[26,26]), Span("mL", sentence=3440, chars=[132,133], words=[29,29]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[85,88], words=[15,15]), Span("11", sentence=3440, chars=[98,99], words=[19,19]), Span("pg", sentence=3440, chars=[129,130], words=[27,27]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[85,88], words=[15,15]), Span("11", sentence=3440, chars=[98,99], words=[19,19]), Span("mL", sentence=3440, chars=[175,176], words=[41,41]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[85,88], words=[15,15]), Span("11", sentence=3440, chars=[98,99], words=[19,19]), Span("pg", sentence=3440, chars=[172,173], words=[39,39]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[85,88], words=[15,15]), Span("11", sentence=3440, chars=[98,99], words=[19,19]), Span("mL", sentence=3440, chars=[132,133], words=[29,29]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[85,88], words=[15,15]), Span("41", sentence=3440, chars=[140,141], words=[32,32]), Span("pg", sentence=3440, chars=[129,130], words=[27,27]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[85,88], words=[15,15]), Span("41", sentence=3440, chars=[140,141], words=[32,32]), Span("mL", sentence=3440, chars=[175,176], words=[41,41]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[85,88], words=[15,15]), Span("41", sentence=3440, chars=[140,141], words=[32,32]), Span("pg", sentence=3440, chars=[172,173], words=[39,39]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[85,88], words=[15,15]), Span("41", sentence=3440, chars=[140,141], words=[32,32]), Span("mL", sentence=3440, chars=[132,133], words=[29,29]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[118,121], words=[23,23]), Span("150", sentence=3440, chars=[125,127], words=[26,26]), Span("pg", sentence=3440, chars=[129,130], words=[27,27]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[118,121], words=[23,23]), Span("150", sentence=3440, chars=[125,127], words=[26,26]), Span("mL", sentence=3440, chars=[175,176], words=[41,41]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[118,121], words=[23,23]), Span("150", sentence=3440, chars=[125,127], words=[26,26]), Span("pg", sentence=3440, chars=[172,173], words=[39,39]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[118,121], words=[23,23]), Span("150", sentence=3440, chars=[125,127], words=[26,26]), Span("mL", sentence=3440, chars=[132,133], words=[29,29]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[118,121], words=[23,23]), Span("11", sentence=3440, chars=[98,99], words=[19,19]), Span("pg", sentence=3440, chars=[129,130], words=[27,27]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[118,121], words=[23,23]), Span("11", sentence=3440, chars=[98,99], words=[19,19]), Span("mL", sentence=3440, chars=[175,176], words=[41,41]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[118,121], words=[23,23]), Span("11", sentence=3440, chars=[98,99], words=[19,19]), Span("pg", sentence=3440, chars=[172,173], words=[39,39]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[118,121], words=[23,23]), Span("11", sentence=3440, chars=[98,99], words=[19,19]), Span("mL", sentence=3440, chars=[132,133], words=[29,29]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[118,121], words=[23,23]), Span("41", sentence=3440, chars=[140,141], words=[32,32]), Span("pg", sentence=3440, chars=[129,130], words=[27,27]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[118,121], words=[23,23]), Span("41", sentence=3440, chars=[140,141], words=[32,32]), Span("mL", sentence=3440, chars=[175,176], words=[41,41]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[118,121], words=[23,23]), Span("41", sentence=3440, chars=[140,141], words=[32,32]), Span("pg", sentence=3440, chars=[172,173], words=[39,39]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[118,121], words=[23,23]), Span("41", sentence=3440, chars=[140,141], words=[32,32]), Span("mL", sentence=3440, chars=[132,133], words=[29,29]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[161,164], words=[36,36]), Span("150", sentence=3440, chars=[125,127], words=[26,26]), Span("pg", sentence=3440, chars=[129,130], words=[27,27]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[161,164], words=[36,36]), Span("150", sentence=3440, chars=[125,127], words=[26,26]), Span("mL", sentence=3440, chars=[175,176], words=[41,41]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[161,164], words=[36,36]), Span("150", sentence=3440, chars=[125,127], words=[26,26]), Span("pg", sentence=3440, chars=[172,173], words=[39,39]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[161,164], words=[36,36]), Span("150", sentence=3440, chars=[125,127], words=[26,26]), Span("mL", sentence=3440, chars=[132,133], words=[29,29]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[161,164], words=[36,36]), Span("11", sentence=3440, chars=[98,99], words=[19,19]), Span("pg", sentence=3440, chars=[129,130], words=[27,27]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[161,164], words=[36,36]), Span("11", sentence=3440, chars=[98,99], words=[19,19]), Span("mL", sentence=3440, chars=[175,176], words=[41,41]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[161,164], words=[36,36]), Span("11", sentence=3440, chars=[98,99], words=[19,19]), Span("pg", sentence=3440, chars=[172,173], words=[39,39]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[161,164], words=[36,36]), Span("11", sentence=3440, chars=[98,99], words=[19,19]), Span("mL", sentence=3440, chars=[132,133], words=[29,29]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[161,164], words=[36,36]), Span("41", sentence=3440, chars=[140,141], words=[32,32]), Span("pg", sentence=3440, chars=[129,130], words=[27,27]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[161,164], words=[36,36]), Span("41", sentence=3440, chars=[140,141], words=[32,32]), Span("mL", sentence=3440, chars=[175,176], words=[41,41]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[161,164], words=[36,36]), Span("41", sentence=3440, chars=[140,141], words=[32,32]), Span("pg", sentence=3440, chars=[172,173], words=[39,39]))
# BiomarkerLevelUnit(Span("iPTH", sentence=3440, chars=[161,164], words=[36,36]), Span("41", sentence=3440, chars=[140,141], words=[32,32]), Span("mL", sentence=3440, chars=[132,133], words=[29,29]))
# BiomarkerLevelUnit(Span("INCB039110", sentence=4648, chars=[96,105], words=[20,20]), Span("45", sentence=4648, chars=[249,250], words=[49,49]), Span("mg", sentence=4648, chars=[309,310], words=[64,64]))
# BiomarkerLevelUnit(Span("INCB039110", sentence=4648, chars=[96,105], words=[20,20]), Span("45", sentence=4648, chars=[249,250], words=[49,49]), Span("mg", sentence=4648, chars=[333,334], words=[71,71]))
# BiomarkerLevelUnit(Span("INCB039110", sentence=4648, chars=[96,105], words=[20,20]), Span("45", sentence=4648, chars=[249,250], words=[49,49]), Span("mg", sentence=4648, chars=[289,290], words=[58,58]))
# BiomarkerLevelUnit(Span("INCB039110", sentence=4648, chars=[96,105], words=[20,20]), Span("600", sentence=4648, chars=[329,331], words=[70,70]), Span("mg", sentence=4648, chars=[309,310], words=[64,64]))
# BiomarkerLevelUnit(Span("INCB039110", sentence=4648, chars=[96,105], words=[20,20]), Span("600", sentence=4648, chars=[329,331], words=[70,70]), Span("mg", sentence=4648, chars=[333,334], words=[71,71]))
# BiomarkerLevelUnit(Span("INCB039110", sentence=4648, chars=[96,105], words=[20,20]), Span("600", sentence=4648, chars=[329,331], words=[70,70]), Span("mg", sentence=4648, chars=[289,290], words=[58,58]))
# BiomarkerLevelUnit(Span("INCB039110", sentence=4648, chars=[96,105], words=[20,20]), Span("100", sentence=4648, chars=[285,287], words=[57,57]), Span("mg", sentence=4648, chars=[309,310], words=[64,64]))
# BiomarkerLevelUnit(Span("INCB039110", sentence=4648, chars=[96,105], words=[20,20]), Span("100", sentence=4648, chars=[285,287], words=[57,57]), Span("mg", sentence=4648, chars=[333,334], words=[71,71]))
# BiomarkerLevelUnit(Span("INCB039110", sentence=4648, chars=[96,105], words=[20,20]), Span("100", sentence=4648, chars=[285,287], words=[57,57]), Span("mg", sentence=4648, chars=[289,290], words=[58,58]))
# BiomarkerLevelUnit(Span("INCB039110", sentence=4648, chars=[96,105], words=[20,20]), Span("32", sentence=4648, chars=[257,258], words=[52,52]), Span("mg", sentence=4648, chars=[309,310], words=[64,64]))
# BiomarkerLevelUnit(Span("INCB039110", sentence=4648, chars=[96,105], words=[20,20]), Span("32", sentence=4648, chars=[257,258], words=[52,52]), Span("mg", sentence=4648, chars=[333,334], words=[71,71]))
# BiomarkerLevelUnit(Span("INCB039110", sentence=4648, chars=[96,105], words=[20,20]), Span("32", sentence=4648, chars=[257,258], words=[52,52]), Span("mg", sentence=4648, chars=[289,290], words=[58,58]))
# BiomarkerLevelUnit(Span("INCB039110", sentence=4648, chars=[96,105], words=[20,20]), Span("200", sentence=4648, chars=[305,307], words=[63,63]), Span("mg", sentence=4648, chars=[309,310], words=[64,64]))
# BiomarkerLevelUnit(Span("INCB039110", sentence=4648, chars=[96,105], words=[20,20]), Span("200", sentence=4648, chars=[305,307], words=[63,63]), Span("mg", sentence=4648, chars=[333,334], words=[71,71]))
# BiomarkerLevelUnit(Span("INCB039110", sentence=4648, chars=[96,105], words=[20,20]), Span("200", sentence=4648, chars=[305,307], words=[63,63]), Span("mg", sentence=4648, chars=[289,290], words=[58,58]))
# BiomarkerLevelUnit(Span("INCB039110", sentence=4648, chars=[96,105], words=[20,20]), Span("24", sentence=4648, chars=[409,410], words=[87,87]), Span("mg", sentence=4648, chars=[309,310], words=[64,64]))
# BiomarkerLevelUnit(Span("INCB039110", sentence=4648, chars=[96,105], words=[20,20]), Span("24", sentence=4648, chars=[409,410], words=[87,87]), Span("mg", sentence=4648, chars=[333,334], words=[71,71]))
# BiomarkerLevelUnit(Span("INCB039110", sentence=4648, chars=[96,105], words=[20,20]), Span("24", sentence=4648, chars=[409,410], words=[87,87]), Span("mg", sentence=4648, chars=[289,290], words=[58,58]))
# BiomarkerLevelUnit(Span("INCB039110", sentence=4648, chars=[96,105], words=[20,20]), Span("10", sentence=4648, chars=[245,246], words=[47,47]), Span("mg", sentence=4648, chars=[309,310], words=[64,64]))
# BiomarkerLevelUnit(Span("INCB039110", sentence=4648, chars=[96,105], words=[20,20]), Span("10", sentence=4648, chars=[245,246], words=[47,47]), Span("mg", sentence=4648, chars=[333,334], words=[71,71]))
# BiomarkerLevelUnit(Span("INCB039110", sentence=4648, chars=[96,105], words=[20,20]), Span("10", sentence=4648, chars=[245,246], words=[47,47]), Span("mg", sentence=4648, chars=[289,290], words=[58,58]))
# BiomarkerLevelUnit(Span("JAK1", sentence=4648, chars=[136,139], words=[27,27]), Span("45", sentence=4648, chars=[249,250], words=[49,49]), Span("mg", sentence=4648, chars=[309,310], words=[64,64]))
# BiomarkerLevelUnit(Span("JAK1", sentence=4648, chars=[136,139], words=[27,27]), Span("45", sentence=4648, chars=[249,250], words=[49,49]), Span("mg", sentence=4648, chars=[333,334], words=[71,71]))
# BiomarkerLevelUnit(Span("JAK1", sentence=4648, chars=[136,139], words=[27,27]), Span("45", sentence=4648, chars=[249,250], words=[49,49]), Span("mg", sentence=4648, chars=[289,290], words=[58,58]))
# BiomarkerLevelUnit(Span("JAK1", sentence=4648, chars=[136,139], words=[27,27]), Span("600", sentence=4648, chars=[329,331], words=[70,70]), Span("mg", sentence=4648, chars=[309,310], words=[64,64]))
# BiomarkerLevelUnit(Span("JAK1", sentence=4648, chars=[136,139], words=[27,27]), Span("600", sentence=4648, chars=[329,331], words=[70,70]), Span("mg", sentence=4648, chars=[333,334], words=[71,71]))
# BiomarkerLevelUnit(Span("JAK1", sentence=4648, chars=[136,139], words=[27,27]), Span("600", sentence=4648, chars=[329,331], words=[70,70]), Span("mg", sentence=4648, chars=[289,290], words=[58,58]))
# BiomarkerLevelUnit(Span("JAK1", sentence=4648, chars=[136,139], words=[27,27]), Span("100", sentence=4648, chars=[285,287], words=[57,57]), Span("mg", sentence=4648, chars=[309,310], words=[64,64]))
# BiomarkerLevelUnit(Span("JAK1", sentence=4648, chars=[136,139], words=[27,27]), Span("100", sentence=4648, chars=[285,287], words=[57,57]), Span("mg", sentence=4648, chars=[333,334], words=[71,71]))
# BiomarkerLevelUnit(Span("JAK1", sentence=4648, chars=[136,139], words=[27,27]), Span("100", sentence=4648, chars=[285,287], words=[57,57]), Span("mg", sentence=4648, chars=[289,290], words=[58,58]))
# BiomarkerLevelUnit(Span("JAK1", sentence=4648, chars=[136,139], words=[27,27]), Span("32", sentence=4648, chars=[257,258], words=[52,52]), Span("mg", sentence=4648, chars=[309,310], words=[64,64]))
# BiomarkerLevelUnit(Span("JAK1", sentence=4648, chars=[136,139], words=[27,27]), Span("32", sentence=4648, chars=[257,258], words=[52,52]), Span("mg", sentence=4648, chars=[333,334], words=[71,71]))
# BiomarkerLevelUnit(Span("JAK1", sentence=4648, chars=[136,139], words=[27,27]), Span("32", sentence=4648, chars=[257,258], words=[52,52]), Span("mg", sentence=4648, chars=[289,290], words=[58,58]))
# BiomarkerLevelUnit(Span("JAK1", sentence=4648, chars=[136,139], words=[27,27]), Span("200", sentence=4648, chars=[305,307], words=[63,63]), Span("mg", sentence=4648, chars=[309,310], words=[64,64]))
# BiomarkerLevelUnit(Span("JAK1", sentence=4648, chars=[136,139], words=[27,27]), Span("200", sentence=4648, chars=[305,307], words=[63,63]), Span("mg", sentence=4648, chars=[333,334], words=[71,71]))
# BiomarkerLevelUnit(Span("JAK1", sentence=4648, chars=[136,139], words=[27,27]), Span("200", sentence=4648, chars=[305,307], words=[63,63]), Span("mg", sentence=4648, chars=[289,290], words=[58,58]))
# BiomarkerLevelUnit(Span("JAK1", sentence=4648, chars=[136,139], words=[27,27]), Span("24", sentence=4648, chars=[409,410], words=[87,87]), Span("mg", sentence=4648, chars=[309,310], words=[64,64]))
# BiomarkerLevelUnit(Span("JAK1", sentence=4648, chars=[136,139], words=[27,27]), Span("24", sentence=4648, chars=[409,410], words=[87,87]), Span("mg", sentence=4648, chars=[333,334], words=[71,71]))
# BiomarkerLevelUnit(Span("JAK1", sentence=4648, chars=[136,139], words=[27,27]), Span("24", sentence=4648, chars=[409,410], words=[87,87]), Span("mg", sentence=4648, chars=[289,290], words=[58,58]))
# BiomarkerLevelUnit(Span("JAK1", sentence=4648, chars=[136,139], words=[27,27]), Span("10", sentence=4648, chars=[245,246], words=[47,47]), Span("mg", sentence=4648, chars=[309,310], words=[64,64]))
# BiomarkerLevelUnit(Span("JAK1", sentence=4648, chars=[136,139], words=[27,27]), Span("10", sentence=4648, chars=[245,246], words=[47,47]), Span("mg", sentence=4648, chars=[333,334], words=[71,71]))
# BiomarkerLevelUnit(Span("JAK1", sentence=4648, chars=[136,139], words=[27,27]), Span("10", sentence=4648, chars=[245,246], words=[47,47]), Span("mg", sentence=4648, chars=[289,290], words=[58,58]))
# BiomarkerLevelUnit(Span("ICS", sentence=4122, chars=[24,26], words=[4,4]), Span("20", sentence=4122, chars=[31,32], words=[6,6]), Span("kg", sentence=4122, chars=[37,38], words=[9,9]))
# BiomarkerLevelUnit(Span("ICS", sentence=4122, chars=[24,26], words=[4,4]), Span("20", sentence=4122, chars=[31,32], words=[6,6]), Span("mg", sentence=4122, chars=[34,35], words=[7,7]))
# BiomarkerLevelUnit(Span("mRNA", sentence=2995, chars=[169,172], words=[29,29]), Span("0.05", sentence=2995, chars=[190,193], words=[34,34]), Span("GG", sentence=2995, chars=[104,105], words=[19,19]))
# BiomarkerLevelUnit(Span("mRNA", sentence=2995, chars=[169,172], words=[29,29]), Span("0.05", sentence=2995, chars=[190,193], words=[34,34]), Span("TG", sentence=2995, chars=[98,99], words=[17,17]))
# BiomarkerLevelUnit(Span("TG", sentence=2995, chars=[98,99], words=[17,17]), Span("0.05", sentence=2995, chars=[190,193], words=[34,34]), Span("GG", sentence=2995, chars=[104,105], words=[19,19]))
# BiomarkerLevelUnit(Span("TG", sentence=2995, chars=[98,99], words=[17,17]), Span("0.05", sentence=2995, chars=[190,193], words=[34,34]), Span("TG", sentence=2995, chars=[98,99], words=[17,17]))
# BiomarkerLevelUnit(Span("RANKL", sentence=8467, chars=[139,143], words=[30,30]), Span("10", sentence=8467, chars=[103,104], words=[13,13]), Span("ml", sentence=8467, chars=[135,136], words=[28,28]))
# BiomarkerLevelUnit(Span("RANKL", sentence=8467, chars=[139,143], words=[30,30]), Span("10", sentence=8467, chars=[103,104], words=[13,13]), Span("ng", sentence=8467, chars=[132,133], words=[26,26]))
# BiomarkerLevelUnit(Span("RANKL", sentence=8467, chars=[139,143], words=[30,30]), Span("10", sentence=8467, chars=[103,104], words=[13,13]), Span("ml", sentence=8467, chars=[109,110], words=[17,17]))
# BiomarkerLevelUnit(Span("RANKL", sentence=8467, chars=[139,143], words=[30,30]), Span("10", sentence=8467, chars=[103,104], words=[13,13]), Span("ng", sentence=8467, chars=[106,107], words=[15,15]))
# BiomarkerLevelUnit(Span("RANKL", sentence=8467, chars=[139,143], words=[30,30]), Span("50", sentence=8467, chars=[129,130], words=[24,24]), Span("ml", sentence=8467, chars=[135,136], words=[28,28]))
# BiomarkerLevelUnit(Span("RANKL", sentence=8467, chars=[139,143], words=[30,30]), Span("50", sentence=8467, chars=[129,130], words=[24,24]), Span("ng", sentence=8467, chars=[132,133], words=[26,26]))
# BiomarkerLevelUnit(Span("RANKL", sentence=8467, chars=[139,143], words=[30,30]), Span("50", sentence=8467, chars=[129,130], words=[24,24]), Span("ml", sentence=8467, chars=[109,110], words=[17,17]))
# BiomarkerLevelUnit(Span("RANKL", sentence=8467, chars=[139,143], words=[30,30]), Span("50", sentence=8467, chars=[129,130], words=[24,24]), Span("ng", sentence=8467, chars=[106,107], words=[15,15]))
# BiomarkerLevelUnit(Span("AFP", sentence=3243, chars=[161,163], words=[40,40]), Span("10.0", sentence=3243, chars=[106,109], words=[23,23]), Span("ng", sentence=3243, chars=[111,112], words=[25,25]))
# BiomarkerLevelUnit(Span("AFP", sentence=3243, chars=[161,163], words=[40,40]), Span("10.0", sentence=3243, chars=[106,109], words=[23,23]), Span("ng", sentence=3243, chars=[97,98], words=[19,19]))
# BiomarkerLevelUnit(Span("AFP", sentence=3243, chars=[161,163], words=[40,40]), Span("10.0", sentence=3243, chars=[106,109], words=[23,23]), Span("mL", sentence=3243, chars=[114,115], words=[27,27]))
# BiomarkerLevelUnit(Span("AFP", sentence=3243, chars=[161,163], words=[40,40]), Span("10.0", sentence=3243, chars=[106,109], words=[23,23]), Span("mL", sentence=3243, chars=[100,101], words=[21,21]))
# BiomarkerLevelUnit(Span("AFP", sentence=3243, chars=[161,163], words=[40,40]), Span("10.0", sentence=3243, chars=[106,109], words=[23,23]), Span("fg", sentence=3243, chars=[151,152], words=[36,36]))
# BiomarkerLevelUnit(Span("AFP", sentence=3243, chars=[161,163], words=[40,40]), Span("10.0", sentence=3243, chars=[106,109], words=[23,23]), Span("mL", sentence=3243, chars=[154,155], words=[38,38]))
# BiomarkerLevelUnit(Span("AFP", sentence=3243, chars=[161,163], words=[40,40]), Span("1.0", sentence=3243, chars=[87,89], words=[13,13]), Span("ng", sentence=3243, chars=[111,112], words=[25,25]))
# BiomarkerLevelUnit(Span("AFP", sentence=3243, chars=[161,163], words=[40,40]), Span("1.0", sentence=3243, chars=[87,89], words=[13,13]), Span("ng", sentence=3243, chars=[97,98], words=[19,19]))
# BiomarkerLevelUnit(Span("AFP", sentence=3243, chars=[161,163], words=[40,40]), Span("1.0", sentence=3243, chars=[87,89], words=[13,13]), Span("mL", sentence=3243, chars=[114,115], words=[27,27]))
# BiomarkerLevelUnit(Span("AFP", sentence=3243, chars=[161,163], words=[40,40]), Span("1.0", sentence=3243, chars=[87,89], words=[13,13]), Span("mL", sentence=3243, chars=[100,101], words=[21,21]))
# BiomarkerLevelUnit(Span("AFP", sentence=3243, chars=[161,163], words=[40,40]), Span("1.0", sentence=3243, chars=[87,89], words=[13,13]), Span("fg", sentence=3243, chars=[151,152], words=[36,36]))
# BiomarkerLevelUnit(Span("AFP", sentence=3243, chars=[161,163], words=[40,40]), Span("1.0", sentence=3243, chars=[87,89], words=[13,13]), Span("mL", sentence=3243, chars=[154,155], words=[38,38]))
# BiomarkerLevelUnit(Span("AFP", sentence=3243, chars=[161,163], words=[40,40]), Span("10", sentence=3243, chars=[93,94], words=[17,17]), Span("ng", sentence=3243, chars=[111,112], words=[25,25]))
# BiomarkerLevelUnit(Span("AFP", sentence=3243, chars=[161,163], words=[40,40]), Span("10", sentence=3243, chars=[93,94], words=[17,17]), Span("ng", sentence=3243, chars=[97,98], words=[19,19]))
# ...
# BiomarkerLevelUnit(Span("LPS", sentence=1561, chars=[113,115], words=[23,23]), Span("20", sentence=1561, chars=[32,33], words=[7,7]), Span("mg", sentence=1561, chars=[35,36], words=[8,8]))
# BiomarkerLevelUnit(Span("LPS", sentence=1561, chars=[113,115], words=[23,23]), Span("20", sentence=1561, chars=[32,33], words=[7,7]), Span("kg", sentence=1561, chars=[123,124], words=[28,28]))
# BiomarkerLevelUnit(Span("LPS", sentence=1561, chars=[113,115], words=[23,23]), Span("20", sentence=1561, chars=[32,33], words=[7,7]), Span("mg", sentence=1561, chars=[120,121], words=[26,26]))
# BiomarkerLevelUnit(Span("LPS", sentence=1561, chars=[113,115], words=[23,23]), Span("20", sentence=1561, chars=[32,33], words=[7,7]), Span("kg", sentence=1561, chars=[38,39], words=[10,10]))
# BiomarkerLevelUnit(Span("LPS", sentence=1561, chars=[113,115], words=[23,23]), Span("1", sentence=1561, chars=[118,118], words=[25,25]), Span("mg", sentence=1561, chars=[35,36], words=[8,8]))
# BiomarkerLevelUnit(Span("LPS", sentence=1561, chars=[113,115], words=[23,23]), Span("1", sentence=1561, chars=[118,118], words=[25,25]), Span("kg", sentence=1561, chars=[123,124], words=[28,28]))
# BiomarkerLevelUnit(Span("LPS", sentence=1561, chars=[113,115], words=[23,23]), Span("1", sentence=1561, chars=[118,118], words=[25,25]), Span("mg", sentence=1561, chars=[120,121], words=[26,26]))
# BiomarkerLevelUnit(Span("LPS", sentence=1561, chars=[113,115], words=[23,23]), Span("1", sentence=1561, chars=[118,118], words=[25,25]), Span("kg", sentence=1561, chars=[38,39], words=[10,10]))
# BiomarkerLevelUnit(Span("CI", sentence=7291, chars=[165,166], words=[26,26]), Span("0.35", sentence=7291, chars=[169,172], words=[28,28]), Span("mmol", sentence=7291, chars=[186,189], words=[34,34]))
# BiomarkerLevelUnit(Span("CI", sentence=7291, chars=[165,166], words=[26,26]), Span("1.07", sentence=7291, chars=[175,178], words=[30,30]), Span("mmol", sentence=7291, chars=[186,189], words=[34,34]))
# BiomarkerLevelUnit(Span("CI", sentence=7291, chars=[165,166], words=[26,26]), Span("0.61", sentence=7291, chars=[155,158], words=[23,23]), Span("mmol", sentence=7291, chars=[186,189], words=[34,34]))
# BiomarkerLevelUnit(Span("CI", sentence=7291, chars=[165,166], words=[26,26]), Span("1", sentence=7291, chars=[184,184], words=[32,32]), Span("mmol", sentence=7291, chars=[186,189], words=[34,34]))
# BiomarkerLevelUnit(Span("MR", sentence=7291, chars=[8,9], words=[1,1]), Span("0.35", sentence=7291, chars=[169,172], words=[28,28]), Span("mmol", sentence=7291, chars=[186,189], words=[34,34]))
# BiomarkerLevelUnit(Span("MR", sentence=7291, chars=[8,9], words=[1,1]), Span("1.07", sentence=7291, chars=[175,178], words=[30,30]), Span("mmol", sentence=7291, chars=[186,189], words=[34,34]))
# BiomarkerLevelUnit(Span("MR", sentence=7291, chars=[8,9], words=[1,1]), Span("0.61", sentence=7291, chars=[155,158], words=[23,23]), Span("mmol", sentence=7291, chars=[186,189], words=[34,34]))
# BiomarkerLevelUnit(Span("MR", sentence=7291, chars=[8,9], words=[1,1]), Span("1", sentence=7291, chars=[184,184], words=[32,32]), Span("mmol", sentence=7291, chars=[186,189], words=[34,34]))
# BiomarkerLevelUnit(Span("PUFA", sentence=9113, chars=[22,25], words=[3,3]), Span("8", sentence=9113, chars=[32,32], words=[7,7]), Span("ng", sentence=9113, chars=[147,148], words=[36,36]))
# BiomarkerLevelUnit(Span("PUFA", sentence=9113, chars=[22,25], words=[3,3]), Span("8", sentence=9113, chars=[32,32], words=[7,7]), Span("kg", sentence=9113, chars=[150,151], words=[38,38]))
# BiomarkerLevelUnit(Span("PUFA", sentence=9113, chars=[22,25], words=[3,3]), Span("0.6", sentence=9113, chars=[143,145], words=[35,35]), Span("ng", sentence=9113, chars=[147,148], words=[36,36]))
# BiomarkerLevelUnit(Span("PUFA", sentence=9113, chars=[22,25], words=[3,3]), Span("0.6", sentence=9113, chars=[143,145], words=[35,35]), Span("kg", sentence=9113, chars=[150,151], words=[38,38]))
# BiomarkerLevelUnit(Span("PUFA", sentence=9113, chars=[22,25], words=[3,3]), Span("6", sentence=9113, chars=[79,79], words=[22,22]), Span("ng", sentence=9113, chars=[147,148], words=[36,36]))
# BiomarkerLevelUnit(Span("PUFA", sentence=9113, chars=[22,25], words=[3,3]), Span("6", sentence=9113, chars=[79,79], words=[22,22]), Span("kg", sentence=9113, chars=[150,151], words=[38,38]))
# BiomarkerLevelUnit(Span("LPS", sentence=9113, chars=[139,141], words=[34,34]), Span("8", sentence=9113, chars=[32,32], words=[7,7]), Span("ng", sentence=9113, chars=[147,148], words=[36,36]))
# BiomarkerLevelUnit(Span("LPS", sentence=9113, chars=[139,141], words=[34,34]), Span("8", sentence=9113, chars=[32,32], words=[7,7]), Span("kg", sentence=9113, chars=[150,151], words=[38,38]))
# BiomarkerLevelUnit(Span("LPS", sentence=9113, chars=[139,141], words=[34,34]), Span("0.6", sentence=9113, chars=[143,145], words=[35,35]), Span("ng", sentence=9113, chars=[147,148], words=[36,36]))
# BiomarkerLevelUnit(Span("LPS", sentence=9113, chars=[139,141], words=[34,34]), Span("0.6", sentence=9113, chars=[143,145], words=[35,35]), Span("kg", sentence=9113, chars=[150,151], words=[38,38]))
# BiomarkerLevelUnit(Span("LPS", sentence=9113, chars=[139,141], words=[34,34]), Span("6", sentence=9113, chars=[79,79], words=[22,22]), Span("ng", sentence=9113, chars=[147,148], words=[36,36]))
# BiomarkerLevelUnit(Span("LPS", sentence=9113, chars=[139,141], words=[34,34]), Span("6", sentence=9113, chars=[79,79], words=[22,22]), Span("kg", sentence=9113, chars=[150,151], words=[38,38]))
# BiomarkerLevelUnit(Span("DHA", sentence=9113, chars=[50,52], words=[14,14]), Span("8", sentence=9113, chars=[32,32], words=[7,7]), Span("ng", sentence=9113, chars=[147,148], words=[36,36]))
# BiomarkerLevelUnit(Span("DHA", sentence=9113, chars=[50,52], words=[14,14]), Span("8", sentence=9113, chars=[32,32], words=[7,7]), Span("kg", sentence=9113, chars=[150,151], words=[38,38]))
# BiomarkerLevelUnit(Span("DHA", sentence=9113, chars=[50,52], words=[14,14]), Span("0.6", sentence=9113, chars=[143,145], words=[35,35]), Span("ng", sentence=9113, chars=[147,148], words=[36,36]))
# BiomarkerLevelUnit(Span("DHA", sentence=9113, chars=[50,52], words=[14,14]), Span("0.6", sentence=9113, chars=[143,145], words=[35,35]), Span("kg", sentence=9113, chars=[150,151], words=[38,38]))
# BiomarkerLevelUnit(Span("DHA", sentence=9113, chars=[50,52], words=[14,14]), Span("6", sentence=9113, chars=[79,79], words=[22,22]), Span("ng", sentence=9113, chars=[147,148], words=[36,36]))
# BiomarkerLevelUnit(Span("DHA", sentence=9113, chars=[50,52], words=[14,14]), Span("6", sentence=9113, chars=[79,79], words=[22,22]), Span("kg", sentence=9113, chars=[150,151], words=[38,38]))
# BiomarkerLevelUnit(Span("EPA", sentence=9113, chars=[46,48], words=[12,12]), Span("8", sentence=9113, chars=[32,32], words=[7,7]), Span("ng", sentence=9113, chars=[147,148], words=[36,36]))
# BiomarkerLevelUnit(Span("EPA", sentence=9113, chars=[46,48], words=[12,12]), Span("8", sentence=9113, chars=[32,32], words=[7,7]), Span("kg", sentence=9113, chars=[150,151], words=[38,38]))
# BiomarkerLevelUnit(Span("EPA", sentence=9113, chars=[46,48], words=[12,12]), Span("0.6", sentence=9113, chars=[143,145], words=[35,35]), Span("ng", sentence=9113, chars=[147,148], words=[36,36]))
# BiomarkerLevelUnit(Span("EPA", sentence=9113, chars=[46,48], words=[12,12]), Span("0.6", sentence=9113, chars=[143,145], words=[35,35]), Span("kg", sentence=9113, chars=[150,151], words=[38,38]))
# BiomarkerLevelUnit(Span("EPA", sentence=9113, chars=[46,48], words=[12,12]), Span("6", sentence=9113, chars=[79,79], words=[22,22]), Span("ng", sentence=9113, chars=[147,148], words=[36,36]))
# BiomarkerLevelUnit(Span("EPA", sentence=9113, chars=[46,48], words=[12,12]), Span("6", sentence=9113, chars=[79,79], words=[22,22]), Span("kg", sentence=9113, chars=[150,151], words=[38,38]))
# BiomarkerLevelUnit(Span("n-3", sentence=9113, chars=[18,20], words=[2,2]), Span("8", sentence=9113, chars=[32,32], words=[7,7]), Span("ng", sentence=9113, chars=[147,148], words=[36,36]))
# BiomarkerLevelUnit(Span("n-3", sentence=9113, chars=[18,20], words=[2,2]), Span("8", sentence=9113, chars=[32,32], words=[7,7]), Span("kg", sentence=9113, chars=[150,151], words=[38,38]))
# BiomarkerLevelUnit(Span("n-3", sentence=9113, chars=[18,20], words=[2,2]), Span("0.6", sentence=9113, chars=[143,145], words=[35,35]), Span("ng", sentence=9113, chars=[147,148], words=[36,36]))
# BiomarkerLevelUnit(Span("n-3", sentence=9113, chars=[18,20], words=[2,2]), Span("0.6", sentence=9113, chars=[143,145], words=[35,35]), Span("kg", sentence=9113, chars=[150,151], words=[38,38]))
# BiomarkerLevelUnit(Span("n-3", sentence=9113, chars=[18,20], words=[2,2]), Span("6", sentence=9113, chars=[79,79], words=[22,22]), Span("ng", sentence=9113, chars=[147,148], words=[36,36]))
# BiomarkerLevelUnit(Span("n-3", sentence=9113, chars=[18,20], words=[2,2]), Span("6", sentence=9113, chars=[79,79], words=[22,22]), Span("kg", sentence=9113, chars=[150,151], words=[38,38]))
# BiomarkerLevelUnit(Span("ACR", sentence=12949, chars=[33,35], words=[5,5]), Span("1", sentence=12949, chars=[107,107], words=[25,25]), Span("mg", sentence=12949, chars=[50,51], words=[9,9]))
# BiomarkerLevelUnit(Span("ACR", sentence=12949, chars=[33,35], words=[5,5]), Span("1", sentence=12949, chars=[107,107], words=[25,25]), Span("mg", sentence=12949, chars=[62,63], words=[14,14]))
# BiomarkerLevelUnit(Span("ACR", sentence=12949, chars=[33,35], words=[5,5]), Span("300", sentence=12949, chars=[58,60], words=[13,13]), Span("mg", sentence=12949, chars=[50,51], words=[9,9]))
# BiomarkerLevelUnit(Span("ACR", sentence=12949, chars=[33,35], words=[5,5]), Span("300", sentence=12949, chars=[58,60], words=[13,13]), Span("mg", sentence=12949, chars=[62,63], words=[14,14]))
# BiomarkerLevelUnit(Span("ACR", sentence=12949, chars=[33,35], words=[5,5]), Span("30", sentence=12949, chars=[47,48], words=[8,8]), Span("mg", sentence=12949, chars=[50,51], words=[9,9]))
# BiomarkerLevelUnit(Span("ACR", sentence=12949, chars=[33,35], words=[5,5]), Span("30", sentence=12949, chars=[47,48], words=[8,8]), Span("mg", sentence=12949, chars=[62,63], words=[14,14]))
# BiomarkerLevelUnit(Span("EAE", sentence=9241, chars=[133,135], words=[27,27]), Span("14", sentence=9241, chars=[43,44], words=[12,12]), Span("kg", sentence=9241, chars=[20,21], words=[5,5]))
# BiomarkerLevelUnit(Span("EAE", sentence=9241, chars=[133,135], words=[27,27]), Span("14", sentence=9241, chars=[43,44], words=[12,12]), Span("mg", sentence=9241, chars=[17,18], words=[3,3]))
# BiomarkerLevelUnit(Span("EAE", sentence=9241, chars=[133,135], words=[27,27]), Span("35", sentence=9241, chars=[145,146], words=[30,30]), Span("kg", sentence=9241, chars=[20,21], words=[5,5]))
# BiomarkerLevelUnit(Span("EAE", sentence=9241, chars=[133,135], words=[27,27]), Span("35", sentence=9241, chars=[145,146], words=[30,30]), Span("mg", sentence=9241, chars=[17,18], words=[3,3]))
# BiomarkerLevelUnit(Span("EAE", sentence=9241, chars=[133,135], words=[27,27]), Span("21", sentence=9241, chars=[29,30], words=[8,8]), Span("kg", sentence=9241, chars=[20,21], words=[5,5]))
# BiomarkerLevelUnit(Span("EAE", sentence=9241, chars=[133,135], words=[27,27]), Span("21", sentence=9241, chars=[29,30], words=[8,8]), Span("mg", sentence=9241, chars=[17,18], words=[3,3]))
# BiomarkerLevelUnit(Span("EAE", sentence=9241, chars=[133,135], words=[27,27]), Span("0.3", sentence=9241, chars=[13,15], words=[2,2]), Span("kg", sentence=9241, chars=[20,21], words=[5,5]))
# BiomarkerLevelUnit(Span("EAE", sentence=9241, chars=[133,135], words=[27,27]), Span("0.3", sentence=9241, chars=[13,15], words=[2,2]), Span("mg", sentence=9241, chars=[17,18], words=[3,3]))
# BiomarkerLevelUnit(Span("EAE", sentence=9241, chars=[133,135], words=[27,27]), Span("1", sentence=9241, chars=[150,150], words=[32,32]), Span("kg", sentence=9241, chars=[20,21], words=[5,5]))
# BiomarkerLevelUnit(Span("EAE", sentence=9241, chars=[133,135], words=[27,27]), Span("1", sentence=9241, chars=[150,150], words=[32,32]), Span("mg", sentence=9241, chars=[17,18], words=[3,3]))
# BiomarkerLevelUnit(Span("EAE", sentence=9234, chars=[213,215], words=[41,41]), Span("7", sentence=9234, chars=[46,46], words=[12,12]), Span("kg", sentence=9234, chars=[21,22], words=[5,5]))
# BiomarkerLevelUnit(Span("EAE", sentence=9234, chars=[213,215], words=[41,41]), Span("7", sentence=9234, chars=[46,46], words=[12,12]), Span("mg", sentence=9234, chars=[18,19], words=[3,3]))
# BiomarkerLevelUnit(Span("EAE", sentence=9234, chars=[213,215], words=[41,41]), Span("0.3", sentence=9234, chars=[14,16], words=[2,2]), Span("kg", sentence=9234, chars=[21,22], words=[5,5]))
# BiomarkerLevelUnit(Span("EAE", sentence=9234, chars=[213,215], words=[41,41]), Span("0.3", sentence=9234, chars=[14,16], words=[2,2]), Span("mg", sentence=9234, chars=[18,19], words=[3,3]))
# BiomarkerLevelUnit(Span("EAE", sentence=9234, chars=[213,215], words=[41,41]), Span("14", sentence=9234, chars=[28,29], words=[7,7]), Span("kg", sentence=9234, chars=[21,22], words=[5,5]))
# BiomarkerLevelUnit(Span("EAE", sentence=9234, chars=[213,215], words=[41,41]), Span("14", sentence=9234, chars=[28,29], words=[7,7]), Span("mg", sentence=9234, chars=[18,19], words=[3,3]))
# BiomarkerLevelUnit(Span("ACR", sentence=12951, chars=[24,26], words=[3,3]), Span("300", sentence=12951, chars=[42,44], words=[10,10]), Span("mg", sentence=12951, chars=[46,47], words=[11,11]))
# BiomarkerLevelUnit(Span("ACR", sentence=12951, chars=[24,26], words=[3,3]), Span("300", sentence=12951, chars=[42,44], words=[10,10]), Span("mg", sentence=12951, chars=[32,33], words=[5,5]))
# BiomarkerLevelUnit(Span("MMAD", sentence=2566, chars=[60,63], words=[13,13]), Span("22.5", sentence=2566, chars=[129,132], words=[36,36]), Span("mg", sentence=2566, chars=[119,120], words=[31,31]))
# BiomarkerLevelUnit(Span("MMAD", sentence=2566, chars=[60,63], words=[13,13]), Span("2.1", sentence=2566, chars=[66,68], words=[15,15]), Span("mg", sentence=2566, chars=[119,120], words=[31,31]))
# BiomarkerLevelUnit(Span("MMAD", sentence=2566, chars=[60,63], words=[13,13]), Span("16", sentence=2566, chars=[116,117], words=[29,29]), Span("mg", sentence=2566, chars=[119,120], words=[31,31]))
# BiomarkerLevelUnit(Span("MMAD", sentence=2566, chars=[60,63], words=[13,13]), Span("1", sentence=2566, chars=[106,106], words=[24,24]), Span("mg", sentence=2566, chars=[119,120], words=[31,31]))
# BiomarkerLevelUnit(Span("MMAD", sentence=2566, chars=[60,63], words=[13,13]), Span("12", sentence=2566, chars=[187,188], words=[48,48]), Span("mg", sentence=2566, chars=[119,120], words=[31,31]))
# BiomarkerLevelUnit(Span("MMAD", sentence=2566, chars=[60,63], words=[13,13]), Span("4", sentence=2566, chars=[109,109], words=[26,26]), Span("mg", sentence=2566, chars=[119,120], words=[31,31]))
# BiomarkerLevelUnit(Span("MMAD", sentence=2566, chars=[60,63], words=[13,13]), Span("22.5", sentence=2566, chars=[202,205], words=[52,52]), Span("mg", sentence=2566, chars=[119,120], words=[31,31]))
# BiomarkerLevelUnit(Span("MMAD", sentence=2566, chars=[60,63], words=[13,13]), Span("6", sentence=2566, chars=[177,177], words=[45,45]), Span("mg", sentence=2566, chars=[119,120], words=[31,31]))
# BiomarkerLevelUnit(Span("TAIT", sentence=3013, chars=[38,41], words=[6,6]), Span("29.3", sentence=3013, chars=[110,113], words=[22,22]), Span("ng", sentence=3013, chars=[100,101], words=[17,17]))
# BiomarkerLevelUnit(Span("TAIT", sentence=3013, chars=[38,41], words=[6,6]), Span("9.4", sentence=3013, chars=[96,98], words=[16,16]), Span("ng", sentence=3013, chars=[100,101], words=[17,17]))
# BiomarkerLevelUnit(Span("PCR", sentence=3013, chars=[71,73], words=[11,11]), Span("29.3", sentence=3013, chars=[110,113], words=[22,22]), Span("ng", sentence=3013, chars=[100,101], words=[17,17]))
# BiomarkerLevelUnit(Span("PCR", sentence=3013, chars=[71,73], words=[11,11]), Span("9.4", sentence=3013, chars=[96,98], words=[16,16]), Span("ng", sentence=3013, chars=[100,101], words=[17,17]))

# %%
# session.rollback()
# print "Number of dev BD candidates without adj. boosting: ", len(cands_BLU[1])
# add_adj_candidate_BLU(session, BiomarkerLevel, cands_BLU[1], 0)
# # fix_specificity(session, BiomarkerCondition, cands_BC[1])
# print "Number of dev BD candidates with adj. boosting: ", session.query(BiomarkerLevel).filter(BiomarkerLevel.split == 1).count()
# session.commit()
# Out:
# Number of dev BD candidates without adj. boosting:  951
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-5005716d7e23> in <module>()
#       1 session.rollback()
#       2 print "Number of dev BD candidates without adj. boosting: ", len(cands_BLU[1])
# ----> 3 add_adj_candidate_BLU(session, BiomarkerLevel, cands_BLU[1], 0)
#       4 # fix_specificity(session, BiomarkerCondition, cands_BC[1])
#       5 print "Number of dev BD candidates with adj. boosting: ", session.query(BiomarkerLevel).filter(BiomarkerLevel.split == 1).count()
#
# NameError: name 'add_adj_candidate_BLU' is not defined

# %%
from LF import *
LFs_BD = [LF_colon, LF_known_abs, LF_single_letter,
          LF_roman_numeral, LF_common_2000, LF_same_thing_BD]

# %%
from snorkel.annotations import LabelAnnotator
BD_labeler = LabelAnnotator(lfs=LFs_BD)

# %%
np.random.seed(1701)
# %time L_train_BD = BD_labeler.apply(split=0)
L_train_BD

# %%
# %time L_train_BD = BD_labeler.load_matrix(session, split=0)
L_train_BD

# %%
L_train_BD.get_candidate(session, 0)

# %%
L_train_BD.get_key(session, 0)

# %%
from snorkel.learning import GenerativeModel

gen_model = GenerativeModel()
gen_model.train(L_train_BD, epochs=100, decay=0.95, step_size=0.1 / L_train_BD.shape[0], reg_param=1e-6)

# %%
gen_model.weights.lf_accuracy

# %%
train_marginals = gen_model.marginals(L_train_BD)

# %%
import matplotlib.pyplot as plt
plt.hist(train_marginals, bins=20)
plt.show()

# %%
L_dev = BD_labeler.apply_existing(split=1)

# %%
from snorkel.annotations import save_marginals
# %time save_marginals(session, L_train_BD, train_marginals)

# %%
from snorkel.annotations import load_marginals

train_marginals = load_marginals(session, split=0)

# %%
train_cands = session.query(BiomarkerDrug).filter(BiomarkerDrug.split == 0).order_by(BiomarkerDrug.id).all()
dev_cands   = session.query(BiomarkerDrug).filter(BiomarkerDrug.split == 1).order_by(BiomarkerDrug.id).all()
test_cands  = session.query(BiomarkerDrug).filter(BiomarkerDrug.split == 2).order_by(BiomarkerDrug.id).all()

# %%
from snorkel.annotations import load_gold_labels
load_external_labels(session, BiomarkerDrug, 'Biomarker', 'Drug', 'articles/drug_gold_labels.tsv', dev_cands, annotator_name='gold')
load_external_labels(session, BiomarkerDrug, 'Biomarker', 'Drug', 'articles/drug_test_labels.tsv', test_cands, annotator_name='gold')

L_gold_dev  = load_gold_labels(session, annotator_name='gold', split=1)
L_gold_test = load_gold_labels(session, annotator_name='gold', split=2)

# %%
print len(train_cands)
print len(dev_cands)

# %%
from snorkel.learning.disc_models.rnn import reRNN

train_kwargs = {
    'lr':         0.01,
    'dim':        50,
    'n_epochs':   10,
    'dropout':    0.25,
    'print_freq': 1,
    'max_sentence_length': 100
}

lstm = reRNN(seed=1701, n_threads=None)
lstm.train(train_cands, train_marginals, X_dev=dev_cands, Y_dev=L_gold_dev, **train_kwargs)

# %%
p, r, f1 = lstm.score(test_cands, L_gold_test)
print("Prec: {0:.3f}, Recall: {1:.3f}, F1 Score: {2:.3f}".format(p, r, f1))

# %%
tp, fp, tn, fn = lstm.error_analysis(session, test_cands, L_gold_test)

# %%
lstm.save_marginals(session, test_cands)

# %%
predictions = lstm.predictions(train_cands)

# %%
i = 0
for prediction in predictions: 
    if(prediction == 1):
        i+=1
print i

# %%
i = 0
while( i< len(train_cands)):
    print("Candidate: {}. Prediction: {}").format(train_cands[i], predictions[i])
    i += 1

# %%
lstm.save()
