# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
import matplotlib.pyplot as plt
from six.moves.cPickle import load
import cPickle
import numpy as np

from snorkel import SnorkelSession
from snorkel.parser import XMLMultiDocPreprocessor, CorpusParser
from snorkel.parser.spacy_parser import Spacy
from snorkel.parser.corenlp import StanfordCoreNLPServer
from snorkel.models import Document, Sentence, Candidate, candidate_subclass
from snorkel.candidates import Ngrams, CandidateExtractor
from snorkel.viewer import SentenceNgramViewer
from snorkel.annotations import LabelAnnotator, load_gold_labels, FeatureAnnotator, save_marginals, load_marginals
from snorkel.learning import SparseLogisticRegression, GenerativeModel, RandomSearch
from snorkel.learning.structure import DependencySelector
from snorkel.learning.utils import MentionScorer
# from snorkel.contrib.rnn import reRNN

import matchers
import LF
from candidate_adjective_fixer import *
from load_external_annotations_new import load_external_labels
# Out:
# /Users/gmachiraju/py2_kernel/lib/python2.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 162 of the file /usr/local/Cellar/python/2.7.9/Frameworks/Python.framework/Versions/2.7/lib/python2.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
#------------------
# Helper Functions
#------------------

def grabCandidates(extractor, schema):
    # Candidate Counts
    for k, sents in enumerate([train_sents, dev_sents, test_sents]):
        extractor.apply(sents, split=k, clear=False)
        print "Number of candidates: ", session.query(schema).filter(schema.split == k).count()
        session.commit()
        
    train_cands = session.query(schema).filter(
        schema.split == 0).all()
    dev_cands = session.query(schema).filter(
        schema.split == 1).all()
    test_cands = session.query(schema).filter(
        schema.split == 2).all()

    return [train_cands, dev_cands, test_cands]

# %%
#-----------------------
# Setup & Preprocessing
#-----------------------

# Instantiate the Session
session = SnorkelSession()

# Doc Preprocessing
file_path = 'articles/training.xml'
train_preprocessor = XMLMultiDocPreprocessor(
    path=file_path,
    doc='.//article',
    text='.//front/article-meta/abstract/p/text()',
    id='.//front/article-meta/article-id/text()'
)

file_path = 'articles/development.xml'
dev_preprocessor = XMLMultiDocPreprocessor(
    path=file_path,
    doc='.//document',
    text='.//passage/text/text()',
    id='.//id/text()'
)

file_path = 'articles/testcorpus.xml'
test_preprocessor = XMLMultiDocPreprocessor(
    path=file_path,
    doc='.//document',
    text='.//passage/text/text()',
    id='.//id/text()'
)

# Parsing
# corenlp_server = StanfordCoreNLPServer(version="3.6.0", num_threads=4, port=12348)
# corpus_parser = CorpusParser(corenlp_server, parser=Spacy())
corpus_parser = CorpusParser(parser=Spacy())
# corpus_parser = CorpusParser()

# Note: Parallelism can be run with a Postgres DBMS, but not SQLite
corpus_parser.apply(list(train_preprocessor))
corpus_parser.apply(list(dev_preprocessor), clear=False)
corpus_parser.apply(list(test_preprocessor), clear=False)
# Out:
# Clearing existing...
# Running UDF...
# [========================================] 100%
#
# Running UDF...
# [========================================] 100%
#
# Running UDF...
# [========================================] 100%

# %%
# Retrieving Stable IDs for each of the candidate sentences
with open('articles/doc_ids.pkl', 'rb') as f:
    train_ids, dev_ids, test_ids = load(f)

train_ids, dev_ids, test_ids = set(train_ids), set(dev_ids), set(test_ids)
train_sents, dev_sents, test_sents = set(), set(), set()
docs = session.query(Document).order_by(Document.name).all()


# Assigning each sentence to {train,dev,test}-set based on Stable ID
for i, doc in enumerate(docs):
    for s in doc.sentences:
        if doc.name in train_ids:
            train_sents.add(s)
        elif doc.name in dev_ids:
            dev_sents.add(s)
        elif doc.name in test_ids:
            test_sents.add(s)
        else:
            raise Exception(
                'ID <{0}> not found in any id set'.format(doc.name))

# %%
#----------------------
# Candidate Extraction
#----------------------

# Defining the Candidate Schemas
BiomarkerCondition = candidate_subclass('BiomarkerCondition', ['biomarker', 'condition'])
BiomarkerDrug = candidate_subclass('BiomarkerDrug', ['biomarker', 'drug'])
BiomarkerMedium = candidate_subclass('BiomarkerMedium', ['biomarker', 'medium'])
BiomarkerType = candidate_subclass('BiomarkerType', ['biomarker', 'typ3'])
# BiomarkerLevelUnit = candidate_subclass('BiomarkerLevelUnit', ['biomarker', 'level', 'unit'])
#can eventually add MEASUREMENT and COHORT SIZE among other entities

# N-grams: the probabilistic search space of our entities
biomarker_ngrams = Ngrams(n_max=1)
condition_ngrams = Ngrams(n_max=7)
drug_ngrams = Ngrams(n_max=5)
medium_ngrams = Ngrams(n_max=5)
type_ngrams = Ngrams(n_max=5)  # <--- Q: should we cut these down?
# level_ngrams = Ngrams(n_max=1)
# unit_ngrams = Ngrams(n_max=1)

# Construct our Matchers
bMatcher = matchers.getBiomarkerMatcher()
cMatcher = matchers.getConditionMatcher()
dMatcher = matchers.getDrugMatcher()
mMatcher = matchers.getMediumMatcher()
tMatcher = matchers.getTypeMatcher()
# lMatcher = matchers.getLevelMatcher()
# uMatcher = matchers.getUnitMatcher()

# Building the CandidateExtractors
candidate_extractor_BC = CandidateExtractor(BiomarkerCondition, [biomarker_ngrams, condition_ngrams], [bMatcher, cMatcher])
candidate_extractor_BD = CandidateExtractor(BiomarkerDrug, [biomarker_ngrams, drug_ngrams], [bMatcher, dMatcher])
candidate_extractor_BM = CandidateExtractor(BiomarkerMedium, [biomarker_ngrams, medium_ngrams], [bMatcher, mMatcher])
candidate_extractor_BT = CandidateExtractor(BiomarkerType, [biomarker_ngrams, type_ngrams], [bMatcher, tMatcher])
# candidate_extractor_BLU = CandidateExtractor(BiomarkerLevelUnit, [biomarker_ngrams, level_ngrams, unit_ngrams], [bMatcher, lMatcher, uMatcher])

# List of Candidate Sets for each relation type: [train, dev, test]
cands_BC = grabCandidates(candidate_extractor_BC, BiomarkerCondition)
cands_BD = grabCandidates(candidate_extractor_BD, BiomarkerDrug)
cands_BM = grabCandidates(candidate_extractor_BM, BiomarkerMedium)
cands_BT = grabCandidates(candidate_extractor_BT, BiomarkerType)
# cands_BLU = grabCandidates(candidate_extractor_BLU, BiomarkerLevelUnit)
# Out:
# ASDFASDF
# Running UDF...
# [========================================] 100%
#
# Number of candidates:  2347
# Running UDF...
# [========================================] 100%
#
# Number of candidates:  622
# Running UDF...
# [========================================] 100%
#
# Number of candidates:  119
# Running UDF...
# [========================================] 100%
#
# Number of candidates:  1057
# Running UDF...
# [========================================] 100%
#
# Number of candidates:  270
# Running UDF...
# [========================================] 100%
#
# Number of candidates:  29
# Running UDF...
# [========================================] 100%
#
# Number of candidates:  781
# Running UDF...
# [========================================] 100%
#
# Number of candidates:  396
# Running UDF...
# [========================================] 100%
#
# Number of candidates:  48
# Running UDF...
# [========================================] 100%
#
# Number of candidates:  2377
# Running UDF...
# [========================================] 100%
#
# Number of candidates:  431
# Running UDF...
# [========================================] 100%
#
# Number of candidates:  45

# %%
session.rollback()

# {train,dev,test} is split order

# Adjective Boosting - BC
print "Number of dev BC candidates without adj. boosting: ", len(cands_BC[1])
add_adj_candidate_BC(session, BiomarkerCondition, cands_BC[1], 0)
# fix_specificity(session, BiomarkerCondition, cands_BC[1])
print "Number of dev BC candidates with adj. boosting: ", session.query(BiomarkerCondition).filter(BiomarkerCondition.split == 1).count()
session.commit()

# Adjective Boosting - BD
print "Number of dev BD candidates without adj. boosting: ", len(cands_BD[1])
add_adj_candidate_BD(session, BiomarkerDrug, cands_BD[1], 0)
print "Number of dev BD candidates with adj. boosting: ", session.query(BiomarkerDrug).filter(BiomarkerDrug.split == 1).count()
session.commit()

# Adjective Boosting - BM
print "Number of dev BM candidates without adj. boosting: ", len(cands_BM[1])
add_adj_candidate_BM(session, BiomarkerMedium, cands_BM[1], 0)
print "Number of dev BM candidates with adj. boosting: ", session.query(BiomarkerMedium).filter(BiomarkerMedium.split == 1).count()
session.commit()

# Adjective Boosting - BT (none as of now)
# Adjective Boosting - BLU (none as of now)
# Out:
# Number of dev BC candidates without adj. boosting:  622
# Checking Biomarker: 28261322::span:154:156
# Checking Condition: 28261322::span:82:100
# 0
# Couldn't find: 28261322::span:82:100
# ADDING NEW CANDIDATE
# Checking Biomarker: 28261322::span:67:69
# Checking Condition: 28261322::span:82:100
# 1
# Checking Biomarker: 28261204::span:1301:1304
# Checking Condition: 28261204::span:110:124
# 0
# Couldn't find: 28261204::span:110:124
# ADDING NEW CANDIDATE
# Checking Biomarker: 28261204::span:1223:1226
# Checking Condition: 28261204::span:110:124
# 1
# Checking Biomarker: 28261204::span:1451:1454
# Checking Condition: 28261204::span:45:61
# 0
# Couldn't find: 28261204::span:45:61
# ADDING NEW CANDIDATE
# Checking Biomarker: 28263981::span:17:20
# Checking Condition: 28263981::span:70:103
# 0
# Couldn't find: 28263981::span:70:103
# ADDING NEW CANDIDATE
# Checking Biomarker: 28263981::span:272:275
# Checking Condition: 28263981::span:100:133
# 0
# Couldn't find: 28263981::span:100:133
# ADDING NEW CANDIDATE
# Checking Biomarker: 28263981::span:161:164
# Checking Condition: 28263981::span:100:133
# 1
# Checking Biomarker: 28263981::span:242:245
# Checking Condition: 28263981::span:100:133
# 1
# Checking Biomarker: 28261345::span:1127:1130
# Checking Condition: 28261345::span:46:68
# 0
# Couldn't find: 28261345::span:46:68
# ADDING NEW CANDIDATE
# Checking Biomarker: 28261345::span:1159:1163
# Checking Condition: 28261345::span:46:68
# 1
# Checking Biomarker: 28261345::span:1082:1084
# Checking Condition: 28261345::span:46:68
# 1
# Checking Biomarker: 28261345::span:1276:1280
# Checking Condition: 28261345::span:46:68
# 1
# Checking Biomarker: 28261345::span:1359:1363
# Checking Condition: 28261345::span:46:68
# 1
# Checking Biomarker: 28261345::span:1222:1223
# Checking Condition: 28261345::span:46:68
# 1
# Checking Biomarker: 28260933::span:1476:1485
# Checking Condition: 28260933::span:85:117
# 0
# Couldn't find: 28260933::span:85:117
# ADDING NEW CANDIDATE
# Checking Biomarker: 28260933::span:1488:1490
# Checking Condition: 28260933::span:85:117
# 1
# Checking Biomarker: 28260933::span:1557:1559
# Checking Condition: 28260933::span:85:117
# 1
# Checking Biomarker: 28260649::span:206:215
# Checking Condition: 28260649::span:97:129
# 0
# Couldn't find: 28260649::span:97:129
# ADDING NEW CANDIDATE
# Checking Biomarker: 28260649::span:338:340
# Checking Condition: 28260649::span:97:129
# 1
# Checking Biomarker: 28260162::span:108:114
# Checking Condition: 28260162::span:92:119
# 0
# Couldn't find: 28260162::span:92:119
# ADDING NEW CANDIDATE
# Checking Biomarker: 28262773::span:1334:1336
# Checking Condition: 28262773::span:140:157
# 0
# Couldn't find: 28262773::span:140:157
# ADDING NEW CANDIDATE
# Checking Biomarker: 28261562::span:1627:1631
# Checking Condition: 28261562::span:85:113
# 0
# Couldn't find: 28261562::span:85:113
# ADDING NEW CANDIDATE
# Checking Biomarker: 28262197::span:1697:1706
# Checking Condition: 28262197::span:16:34
# 0
# Couldn't find: 28262197::span:16:34
# ADDING NEW CANDIDATE
# Checking Biomarker: 28260162::span:618:624
# Checking Condition: 28260162::span:97:124
# 0
# Couldn't find: 28260162::span:97:124
# ADDING NEW CANDIDATE
# Checking Biomarker: 28260162::span:1553:1563
# Checking Condition: 28260162::span:124:151
# 0
# Couldn't find: 28260162::span:124:151
# ADDING NEW CANDIDATE
# Checking Biomarker: 28260175::span:157:160
# Checking Condition: 28260175::span:13:47
# 0
# Couldn't find: 28260175::span:13:47
# ADDING NEW CANDIDATE
# Checking Biomarker: 28260175::span:107:113
# Checking Condition: 28260175::span:13:47
# 1
# Checking Biomarker: 28263001::span:707:708
# Checking Condition: 28263001::span:66:80
# 0
# Couldn't find: 28263001::span:66:80
# ADDING NEW CANDIDATE
# Checking Biomarker: 28263001::span:578:584
# Checking Condition: 28263001::span:66:80
# 1
# Checking Biomarker: 28263001::span:661:663
# Checking Condition: 28263001::span:66:80
# 1
# Checking Biomarker: 28261908::span:1009:1014
# Checking Condition: 28261908::span:488:505
# 0
# Couldn't find: 28261908::span:488:505
# ADDING NEW CANDIDATE
# Checking Biomarker: 28261908::span:1009:1014
# Checking Condition: 28261908::span:330:360
# 0
# Couldn't find: 28261908::span:330:360
# ADDING NEW CANDIDATE
# Checking Biomarker: 28261908::span:1009:1014
# Checking Condition: 28261908::span:176:206
# 0
# Couldn't find: 28261908::span:176:206
# ADDING NEW CANDIDATE
# Checking Biomarker: 28261908::span:1009:1014
# Checking Condition: 28261908::span:442:476
# 0
# Couldn't find: 28261908::span:442:476
# ADDING NEW CANDIDATE
# Checking Biomarker: 28261908::span:1070:1073
# Checking Condition: 28261908::span:488:505
# 1
# Checking Biomarker: 28261908::span:1070:1073
# Checking Condition: 28261908::span:330:360
# 1
# Checking Biomarker: 28261908::span:1070:1073
# Checking Condition: 28261908::span:176:206
# 1
# Checking Biomarker: 28261908::span:1070:1073
# Checking Condition: 28261908::span:442:476
# 1
# Checking Biomarker: 28261908::span:855:859
# Checking Condition: 28261908::span:488:505
# 1
# Checking Biomarker: 28261908::span:855:859
# Checking Condition: 28261908::span:330:360
# 1
# Checking Biomarker: 28261908::span:855:859
# Checking Condition: 28261908::span:176:206
# 1
# Checking Biomarker: 28261908::span:855:859
# Checking Condition: 28261908::span:442:476
# 1
# Checking Biomarker: 28261908::span:802:804
# Checking Condition: 28261908::span:488:505
# 1
# Checking Biomarker: 28261908::span:802:804
# Checking Condition: 28261908::span:330:360
# 1
# Checking Biomarker: 28261908::span:802:804
# Checking Condition: 28261908::span:176:206
# 1
# Checking Biomarker: 28261908::span:802:804
# Checking Condition: 28261908::span:442:476
# 1
# Checking Biomarker: 28264096::span:1680:1681
# Checking Condition: 28264096::span:255:266
# 0
# Couldn't find: 28264096::span:255:266
# ADDING NEW CANDIDATE
# Checking Biomarker: 28264096::span:1760:1761
# Checking Condition: 28264096::span:255:266
# 1
# Checking Biomarker: 28264096::span:1937:1938
# Checking Condition: 28264096::span:255:266
# 1
# Checking Biomarker: 28264096::span:1741:1743
# Checking Condition: 28264096::span:255:266
# 1
# Checking Biomarker: 28264096::span:1666:1667
# Checking Condition: 28264096::span:255:266
# 1
# Checking Biomarker: 28264096::span:1874:1875
# Checking Condition: 28264096::span:255:266
# 1
# Checking Biomarker: 28264096::span:1860:1861
# Checking Condition: 28264096::span:255:266
# 1
# Checking Biomarker: 28264096::span:1809:1811
# Checking Condition: 28264096::span:255:266
# 1
# Checking Biomarker: 28264096::span:1951:1952
# Checking Condition: 28264096::span:255:266
# 1
# Checking Biomarker: 28264096::span:1618:1619
# Checking Condition: 28264096::span:255:266
# 1
# Checking Biomarker: 28264096::span:1613:1615
# Checking Condition: 28264096::span:255:266
# 1
# Checking Biomarker: 28264096::span:1746:1747
# Checking Condition: 28264096::span:255:266
# 1
# Checking Biomarker: 28263391::span:45:48
# Checking Condition: 28263391::span:111:132
# 0
# Couldn't find: 28263391::span:111:132
# ADDING NEW CANDIDATE
# Checking Biomarker: 28263100::span:770:774
# Checking Condition: 28263100::span:63:94
# 0
# Couldn't find: 28263100::span:63:94
# ADDING NEW CANDIDATE
# Checking Biomarker: 28263100::span:770:774
# Checking Condition: 28263100::span:28:46
# 0
# Couldn't find: 28263100::span:28:46
# ADDING NEW CANDIDATE
# Checking Biomarker: 28263100::span:776:779
# Checking Condition: 28263100::span:63:94
# 1
# Checking Biomarker: 28263100::span:776:779
# Checking Condition: 28263100::span:28:46
# 1
# Checking Biomarker: 28263391::span:871:872
# Checking Condition: 28263391::span:70:89
# 0
# Couldn't find: 28263391::span:70:89
# ADDING NEW CANDIDATE
# Checking Biomarker: 28263391::span:381:382
# Checking Condition: 28263391::span:136:150
# 0
# Couldn't find: 28263391::span:136:150
# ADDING NEW CANDIDATE
# Checking Biomarker: 28262798::span:474:478
# Checking Condition: 28262798::span:169:190
# 0
# Couldn't find: 28262798::span:169:190
# ADDING NEW CANDIDATE
# Checking Biomarker: 28262798::span:340:344
# Checking Condition: 28262798::span:169:190
# 1
# Checking Biomarker: 28263391::span:469:471
# Checking Condition: 28263391::span:101:113
# 0
# Couldn't find: 28263391::span:101:113
# ADDING NEW CANDIDATE
# Checking Biomarker: 28263391::span:534:537
# Checking Condition: 28263391::span:101:113
# 1
# Checking Biomarker: 28262798::span:728:729
# Checking Condition: 28262798::span:35:54
# 0
# Couldn't find: 28262798::span:35:54
# ADDING NEW CANDIDATE
# Checking Biomarker: 28262306::span:137:146
# Checking Condition: 28262306::span:60:73
# 0
# Couldn't find: 28262306::span:60:73
# ADDING NEW CANDIDATE
# Checking Biomarker: 28262306::span:378:381
# Checking Condition: 28262306::span:134:147
# 0
# Couldn't find: 28262306::span:134:147
# ADDING NEW CANDIDATE
# Checking Biomarker: 28262306::span:358:361
# Checking Condition: 28262306::span:134:147
# 1
# Checking Biomarker: 28262306::span:507:509
# Checking Condition: 28262306::span:134:147
# 1
# Checking Biomarker: 28262306::span:500:501
# Checking Condition: 28262306::span:134:147
# 1
# Checking Biomarker: 28262306::span:1871:1874
# Checking Condition: 28262306::span:87:100
# 0
# Couldn't find: 28262306::span:87:100
# ADDING NEW CANDIDATE
# Checking Biomarker: 28262306::span:1880:1883
# Checking Condition: 28262306::span:87:100
# 1
# Checking Biomarker: 28260718::span:164:166
# Checking Condition: 28260718::span:132:171
# 0
# Couldn't find: 28260718::span:132:171
# ADDING NEW CANDIDATE
# Checking Biomarker: 28260718::span:217:221
# Checking Condition: 28260718::span:132:171
# 1
# Checking Biomarker: 28262306::span:32:35
# Checking Condition: 28262306::span:85:98
# 0
# Couldn't find: 28262306::span:85:98
# ADDING NEW CANDIDATE
# Checking Biomarker: 28261684::span:168:174
# Checking Condition: 28261684::span:54:67
# 0
# Couldn't find: 28261684::span:54:67
# ADDING NEW CANDIDATE
# Checking Biomarker: 28261684::span:168:174
# Checking Condition: 28261684::span:24:36
# 0
# Couldn't find: 28261684::span:24:36
# ADDING NEW CANDIDATE
# Checking Biomarker: 28262306::span:521:523
# Checking Condition: 28262306::span:75:91
# 0
# Couldn't find: 28262306::span:75:91
# ADDING NEW CANDIDATE
# Checking Biomarker: 28262306::span:512:519
# Checking Condition: 28262306::span:75:91
# 1
# Checking Biomarker: 28262306::span:525:531
# Checking Condition: 28262306::span:75:91
# 1
# Checking Biomarker: 28261908::span:69:78
# Checking Condition: 28261908::span:43:65
# 0
# Couldn't find: 28261908::span:43:65
# ADDING NEW CANDIDATE
# Checking Biomarker: 28261908::span:137:139
# Checking Condition: 28261908::span:43:65
# 1
# Checking Biomarker: 28261908::span:1552:1555
# Checking Condition: 28261908::span:21:42
# 0
# Couldn't find: 28261908::span:21:42
# ADDING NEW CANDIDATE
# Checking Biomarker: 28261341::span:305:307
# Checking Condition: 28261341::span:166:189
# 0
# Couldn't find: 28261341::span:166:189
# ADDING NEW CANDIDATE
# Checking Biomarker: 28261746::span:558:562
# Checking Condition: 28261746::span:59:91
# 0
# Couldn't find: 28261746::span:59:91
# ADDING NEW CANDIDATE
# Checking Biomarker: 28261746::span:320:322
# Checking Condition: 28261746::span:59:91
# 1
# Checking Biomarker: 28261746::span:324:330
# Checking Condition: 28261746::span:59:91
# 1
# Checking Biomarker: 28261746::span:550:555
# Checking Condition: 28261746::span:59:91
# 1
# Checking Biomarker: 28261746::span:569:571
# Checking Condition: 28261746::span:59:91
# 1
# Checking Biomarker: 28261746::span:310:318
# Checking Condition: 28261746::span:59:91
# 1
# Checking Biomarker: 28263294::span:834:839
# Checking Condition: 28263294::span:50:66
# 0
# Couldn't find: 28263294::span:50:66
# ADDING NEW CANDIDATE
# Checking Biomarker: 28261746::span:1064:1066
# Checking Condition: 28261746::span:206:238
# 0
# Couldn't find: 28261746::span:206:238
# ADDING NEW CANDIDATE
# Checking Biomarker: 28261746::span:1240:1242
# Checking Condition: 28261746::span:206:238
# 1
# Checking Biomarker: 28261746::span:968:972
# Checking Condition: 28261746::span:206:238
# 1
# Checking Biomarker: 28261746::span:952:954
# Checking Condition: 28261746::span:206:238
# 1
# Checking Biomarker: 28261746::span:1097:1102
# Checking Condition: 28261746::span:206:238
# 1
# Checking Biomarker: 28261746::span:974:976
# Checking Condition: 28261746::span:206:238
# 1
# Checking Biomarker: 28261746::span:957:961
# Checking Condition: 28261746::span:206:238
# 1
# Checking Biomarker: 28261746::span:1193:1195
# Checking Condition: 28261746::span:206:238
# 1
# Checking Biomarker: 28261746::span:1629:1633
# Checking Condition: 28261746::span:31:62
# 0
# Couldn't find: 28261746::span:31:62
# ADDING NEW CANDIDATE
# Checking Biomarker: 28261746::span:1500:1507
# Checking Condition: 28261746::span:31:62
# 1
# Checking Biomarker: 28261746::span:1643:1647
# Checking Condition: 28261746::span:31:62
# 1
# Checking Biomarker: 28261746::span:1509:1517
# Checking Condition: 28261746::span:31:62
# 1
# Checking Biomarker: 28261336::span:573:574
# Checking Condition: 28261336::span:67:80
# 0
# Couldn't find: 28261336::span:67:80
# ADDING NEW CANDIDATE
# Checking Biomarker: 28261818::span:217:218
# Checking Condition: 28261818::span:155:174
# 0
# Couldn't find: 28261818::span:155:174
# ADDING NEW CANDIDATE
# Checking Biomarker: 28261818::span:221:223
# Checking Condition: 28261818::span:155:174
# 1
# Checking Biomarker: 28261818::span:244:247
# Checking Condition: 28261818::span:155:174
# 1
# Checking Biomarker: 28261818::span:240:241
# Checking Condition: 28261818::span:155:174
# 1
# Checking Biomarker: 28261818::span:126:132
# Checking Condition: 28261818::span:155:174
# 1
# Checking Biomarker: 28261974::span:91:93
# Checking Condition: 28261974::span:91:109
# 0
# Couldn't find: 28261974::span:91:109
# ADDING NEW CANDIDATE
# Checking Biomarker: 28260536::span:727:730
# Checking Condition: 28260536::span:207:220
# 0
# Couldn't find: 28260536::span:207:220
# ADDING NEW CANDIDATE
# Checking Biomarker: 28260759::span:1119:1121
# Checking Condition: 28260759::span:23:40
# 0
# Couldn't find: 28260759::span:23:40
# ADDING NEW CANDIDATE
# Checking Biomarker: 28260759::span:1119:1121
# Checking Condition: 28260759::span:64:85
# 0
# Couldn't find: 28260759::span:64:85
# ADDING NEW CANDIDATE
# Checking Biomarker: 28263742::span:468:470
# Checking Condition: 28263742::span:108:135
# 0
# Couldn't find: 28263742::span:108:135
# ADDING NEW CANDIDATE
# Checking Biomarker: 28263742::span:167:169
# Checking Condition: 28263742::span:108:135
# 1
# Checking Biomarker: 28263742::span:172:177
# Checking Condition: 28263742::span:108:135
# 1
# Checking Biomarker: 28263742::span:304:306
# Checking Condition: 28263742::span:108:135
# 1
# Checking Biomarker: 28263742::span:401:403
# Checking Condition: 28263742::span:108:135
# 1
# Checking Biomarker: 28263742::span:93:104
# Checking Condition: 28263742::span:108:135
# 1
# Checking Biomarker: 28260757::span:505:506
# Checking Condition: 28260757::span:192:214
# 0
# Couldn't find: 28260757::span:192:214
# ADDING NEW CANDIDATE
# Checking Biomarker: 28260757::span:570:572
# Checking Condition: 28260757::span:192:214
# 1
# Checking Biomarker: 28260757::span:532:534
# Checking Condition: 28260757::span:192:214
# 1
# Checking Biomarker: 28260759::span:116:118
# Checking Condition: 28260759::span:6:22
# 0
# Couldn't find: 28260759::span:6:22
# ADDING NEW CANDIDATE
# Checking Biomarker: 28260759::span:570:572
# Checking Condition: 28260759::span:66:98
# 0
# Couldn't find: 28260759::span:66:98
# ADDING NEW CANDIDATE
# Checking Biomarker: 28260759::span:915:917
# Checking Condition: 28260759::span:0:22
# 0
# Couldn't find: 28260759::span:0:22
# ADDING NEW CANDIDATE
# Checking Biomarker: 28261345::span:7:10
# Checking Condition: 28261345::span:59:81
# 0
# Couldn't find: 28261345::span:59:81
# ADDING NEW CANDIDATE
# Checking Biomarker: 28261345::span:550:553
# Checking Condition: 28261345::span:175:197
# 0
# Couldn't find: 28261345::span:175:197
# ADDING NEW CANDIDATE
# Checking Biomarker: 28261345::span:679:681
# Checking Condition: 28261345::span:175:197
# 1
# Checking Biomarker: 28261345::span:689:692
# Checking Condition: 28261345::span:175:197
# 1
# Checking Biomarker: 28261345::span:505:508
# Checking Condition: 28261345::span:175:197
# 1
# Checking Biomarker: 28261345::span:791:794
# Checking Condition: 28261345::span:28:50
# 0
# Couldn't find: 28261345::span:28:50
# ADDING NEW CANDIDATE
# Checking Biomarker: 28261345::span:1648:1649
# Checking Condition: 28261345::span:31:45
# 0
# Couldn't find: 28261345::span:31:45
# ADDING NEW CANDIDATE
# Checking Biomarker: 28261345::span:1552:1554
# Checking Condition: 28261345::span:31:45
# 1
# Checking Biomarker: 28261345::span:1497:1498
# Checking Condition: 28261345::span:31:45
# 1
# Checking Biomarker: 28261345::span:1664:1666
# Checking Condition: 28261345::span:31:45
# 1
# Checking Biomarker: 28261345::span:1839:1842
# Checking Condition: 28261345::span:101:114
# 0
# Couldn't find: 28261345::span:101:114
# ADDING NEW CANDIDATE
# Checking Biomarker: 28260933::span:535:537
# Checking Condition: 28260933::span:63:95
# 0
# Couldn't find: 28260933::span:63:95
# ADDING NEW CANDIDATE
# Checking Biomarker: 28260933::span:526:533
# Checking Condition: 28260933::span:63:95
# 1
# Checking Biomarker: 28260933::span:539:545
# Checking Condition: 28260933::span:63:95
# 1
# Checking Biomarker: 28260933::span:585:587
# Checking Condition: 28260933::span:63:95
# 1
# Checking Biomarker: 28261953::span:27:31
# Checking Condition: 28261953::span:57:76
# 0
# Couldn't find: 28261953::span:57:76
# ADDING NEW CANDIDATE
# Checking Biomarker: 28260718::span:8:12
# Checking Condition: 28260718::span:92:122
# 0
# Couldn't find: 28260718::span:92:122
# ADDING NEW CANDIDATE
# Checking Biomarker: 28264198::span:844:846
# Checking Condition: 28264198::span:99:114
# 0
# Couldn't find: 28264198::span:99:114
# ADDING NEW CANDIDATE
# Checking Biomarker: 28260391::span:1635:1638
# Checking Condition: 28260391::span:63:84
# 0
# Couldn't find: 28260391::span:63:84
# ADDING NEW CANDIDATE
# Checking Biomarker: 28260391::span:1604:1613
# Checking Condition: 28260391::span:63:84
# 1
# Checking Biomarker: 28260391::span:1616:1618
# Checking Condition: 28260391::span:63:84
# 1
# Checking Biomarker: 28262211::span:79:87
# Checking Condition: 28262211::span:185:205
# 0
# Couldn't find: 28262211::span:185:205
# ADDING NEW CANDIDATE
# Checking Biomarker: 28262211::span:319:325
# Checking Condition: 28262211::span:283:317
# 0
# Couldn't find: 28262211::span:283:317
# ADDING NEW CANDIDATE
# Checking Biomarker: 28262211::span:387:389
# Checking Condition: 28262211::span:283:317
# 1
# Checking Biomarker: 28262211::span:305:313
# Checking Condition: 28262211::span:283:317
# 1
# Checking Biomarker: 28262211::span:392:394
# Checking Condition: 28262211::span:283:317
# 1
# Checking Biomarker: 28262211::span:315:317
# Checking Condition: 28262211::span:283:317
# 1
# Checking Biomarker: 28262211::span:383:384
# Checking Condition: 28262211::span:283:317
# 1
# Checking Biomarker: 28262211::span:889:891
# Checking Condition: 28262211::span:213:247
# 0
# Couldn't find: 28262211::span:213:247
# ADDING NEW CANDIDATE
# Checking Biomarker: 28262211::span:889:891
# Checking Condition: 28262211::span:156:177
# 0
# Couldn't find: 28262211::span:156:177
# ADDING NEW CANDIDATE
# Checking Biomarker: 28262211::span:894:896
# Checking Condition: 28262211::span:213:247
# 1
# Checking Biomarker: 28262211::span:894:896
# Checking Condition: 28262211::span:156:177
# 1
# Checking Biomarker: 28262211::span:839:840
# Checking Condition: 28262211::span:213:247
# 1
# Checking Biomarker: 28262211::span:839:840
# Checking Condition: 28262211::span:156:177
# 1
# Checking Biomarker: 28262211::span:805:811
# Checking Condition: 28262211::span:213:247
# 1
# Checking Biomarker: 28262211::span:805:811
# Checking Condition: 28262211::span:156:177
# 1
# Checking Biomarker: 28262211::span:1569:1570
# Checking Condition: 28262211::span:55:67
# 0
# Couldn't find: 28262211::span:55:67
# ADDING NEW CANDIDATE
# Checking Biomarker: 28262211::span:1627:1637
# Checking Condition: 28262211::span:221:233
# 0
# Couldn't find: 28262211::span:221:233
# ADDING NEW CANDIDATE
# Checking Biomarker: 28261371::span:154:159
# Checking Condition: 28261371::span:206:227
# 0
# Couldn't find: 28261371::span:206:227
# ADDING NEW CANDIDATE
# Checking Biomarker: 28261371::span:143:149
# Checking Condition: 28261371::span:206:227
# 1
# Checking Biomarker: 28261371::span:373:375
# Checking Condition: 28261371::span:206:227
# 1
# Checking Biomarker: 28261371::span:151:152
# Checking Condition: 28261371::span:206:227
# 1
# Checking Biomarker: 28262254::span:519:525
# Checking Condition: 28262254::span:84:114
# 0
# Couldn't find: 28262254::span:84:114
# ADDING NEW CANDIDATE
# Checking Biomarker: 28261896::span:1315:1318
# Checking Condition: 28261896::span:97:119
# 0
# Couldn't find: 28261896::span:97:119
# ADDING NEW CANDIDATE
# Checking Biomarker: 28261896::span:1364:1366
# Checking Condition: 28261896::span:97:119
# 1
# Checking Biomarker: 28262322::span:477:483
# Checking Condition: 28262322::span:151:175
# 0
# Couldn't find: 28262322::span:151:175
# ADDING NEW CANDIDATE
# Checking Biomarker: 28262322::span:471:473
# Checking Condition: 28262322::span:151:175
# 1
# Checking Biomarker: 28262322::span:592:595
# Checking Condition: 28262322::span:151:175
# 1
# Checking Biomarker: 28262322::span:521:523
# Checking Condition: 28262322::span:151:175
# 1
# Checking Biomarker: 28261322::span:1331:1333
# Checking Condition: 28261322::span:341:364
# 0
# Couldn't find: 28261322::span:341:364
# ADDING NEW CANDIDATE
# Checking Biomarker: 28261322::span:1204:1206
# Checking Condition: 28261322::span:341:364
# 1
# Checking Biomarker: 28262437::span:532:534
# Checking Condition: 28262437::span:166:196
# 0
# Couldn't find: 28262437::span:166:196
# ADDING NEW CANDIDATE
# Checking Biomarker: 28261284::span:542:545
# Checking Condition: 28261284::span:165:187
# 0
# Couldn't find: 28261284::span:165:187
# ADDING NEW CANDIDATE
# Checking Biomarker: 28261284::span:487:491
# Checking Condition: 28261284::span:165:187
# 1
# Checking Biomarker: 28260391::span:480:482
# Checking Condition: 28260391::span:86:107
# 0
# Couldn't find: 28260391::span:86:107
# ADDING NEW CANDIDATE
# Checking Biomarker: 28260391::span:434:440
# Checking Condition: 28260391::span:86:107
# 1
# Checking Biomarker: 28263037::span:1332:1335
# Checking Condition: 28263037::span:95:116
# 0
# Couldn't find: 28263037::span:95:116
# ADDING NEW CANDIDATE
# Checking Biomarker: 28263037::span:1312:1321
# Checking Condition: 28263037::span:95:116
# 1
# Checking Biomarker: 28263037::span:1460:1462
# Checking Condition: 28263037::span:95:116
# 1
# Checking Biomarker: 28262616::span:113:114
# Checking Condition: 28262616::span:40:52
# 0
# Couldn't find: 28262616::span:40:52
# ADDING NEW CANDIDATE
# Checking Biomarker: 28260907::span:256:260
# Checking Condition: 28260907::span:93:124
# 0
# Couldn't find: 28260907::span:93:124
# ADDING NEW CANDIDATE
# Checking Biomarker: 28261341::span:1446:1448
# Checking Condition: 28261341::span:200:217
# 0
# Couldn't find: 28261341::span:200:217
# ADDING NEW CANDIDATE
# Checking Biomarker: 28260919::span:311:314
# Checking Condition: 28260919::span:90:103
# 0
# Couldn't find: 28260919::span:90:103
# ADDING NEW CANDIDATE
# Checking Biomarker: 28260919::span:311:314
# Checking Condition: 28260919::span:22:35
# 0
# Couldn't find: 28260919::span:22:35
# ADDING NEW CANDIDATE
# Checking Biomarker: 28260919::span:444:446
# Checking Condition: 28260919::span:90:103
# 1
# Checking Biomarker: 28260919::span:444:446
# Checking Condition: 28260919::span:22:35
# 1
# Checking Biomarker: 28263922::span:514:516
# Checking Condition: 28263922::span:148:159
# 0
# Couldn't find: 28263922::span:148:159
# ADDING NEW CANDIDATE
# Checking Biomarker: 28263447::span:171:174
# Checking Condition: 28263447::span:51:86
# 0
# Couldn't find: 28263447::span:51:86
# ADDING NEW CANDIDATE
# Checking Biomarker: 28263447::span:292:296
# Checking Condition: 28263447::span:56:94
# 0
# Couldn't find: 28263447::span:56:94
# ADDING NEW CANDIDATE
# Checking Biomarker: 28263447::span:195:203
# Checking Condition: 28263447::span:56:94
# 1
# Checking Biomarker: 28261325::span:564:566
# Checking Condition: 28261325::span:116:129
# 0
# Couldn't find: 28261325::span:116:129
# ADDING NEW CANDIDATE
# Checking Biomarker: 28262306::span:1068:1071
# Checking Condition: 28262306::span:69:85
# 0
# Couldn't find: 28262306::span:69:85
# ADDING NEW CANDIDATE
# Checking Biomarker: 28261333::span:295:299
# Checking Condition: 28261333::span:151:198
# 0
# Couldn't find: 28261333::span:151:198
# ADDING NEW CANDIDATE
# Finished Processing Existing Candidates
# Number of dev BC candidates with adj. boosting:  622
# Number of dev BD candidates without adj. boosting:  270
#  added to pimonidazole
#  added to pimonidazole
#  added to pemetrexed
#  added to irinotecan
#  added to docetaxel
#  added to pemetrexed
#  added to irinotecan
#  added to docetaxel
#  added to pemetrexed
#  added to irinotecan
#  added to docetaxel
#  added to pemetrexed
#  added to irinotecan
#  added to docetaxel
#  added to pemetrexed
#  added to irinotecan
#  added to docetaxel
#  added to pemetrexed
#  added to irinotecan
#  added to docetaxel
#  added to pimonidazole
# hormone estrogenic  added to estradiol
# Checking Biomarker: 28263535::span:372:374
# Checking Condition: 28263535::span:144:171
# 0
# Couldn't find: 28263535::span:144:171
# ADDING NEW CANDIDATE
#  added to pimonidazole
#  added to pimonidazole
#  added to pimonidazole
#  added to pimonidazole
#  added to pimonidazole
#  added to BMD
#  added to BMD
#  added to cystatin
#  added to cystatin
#  added to cystatin
#  added to ubiquinone
#  added to ubiquinone
#  added to estradiol
#  added to estradiol
#  added to estradiol
#  added to sorafenib
#  added to sorafenib
#  added to sorafenib
#  added to sorafenib
#  added to sorafenib
#  added to sorafenib
#  added to sorafenib
#  added to sorafenib
#  added to sorafenib
#  added to tryptophan
#  added to sorafenib
#  added to sunitinib
#  added to Decitabine
#  added to decitabine
#  added to decitabine
#  added to estradiol
#  added to estradiol
#  added to estradiol
#  added to estradiol
#  added to iron
#  added to iron
#  added to iron
# maternal  added to iron
# Checking Biomarker: 28262197::span:1697:1706
# Checking Condition: 28262197::span:58:70
# 0
# Couldn't find: 28262197::span:58:70
# ADDING NEW CANDIDATE
#  added to sunitinib
#  added to sorafenib
#  added to ascorbic acid
#  added to ascorbic acid
#  added to selenium
#  added to cholesterol
#  added to selenium
#  added to selenium
#  added to cholesterol
#  added to selenium
#  added to selenium
#  added to cholesterol
#  added to selenium
#  added to selenium
#  added to selenium
#  added to selenium
#  added to selenium
#  added to selenium
#  added to selenium
# topical  added to imiquimod
# Checking Biomarker: 28261899::span:46:48
# Checking Condition: 28261899::span:93:109
# 0
# Couldn't find: 28261899::span:93:109
# ADDING NEW CANDIDATE
# oral  added to valcyclovir
# Checking Biomarker: 28261899::span:474:476
# Checking Condition: 28261899::span:183:198
# 0
# Couldn't find: 28261899::span:183:198
# ADDING NEW CANDIDATE
#  added to imiquimod
#  added to fluorouracil
#  added to oxaliplatin
#  added to irinotecan
#  added to gemcitabine
#  added to fluorouracil
#  added to oxaliplatin
#  added to irinotecan
#  added to gemcitabine
#  added to fluorouracil
#  added to oxaliplatin
#  added to irinotecan
#  added to gemcitabine
#  added to fluorouracil
#  added to oxaliplatin
#  added to irinotecan
#  added to gemcitabine
#  added to sorafenib
#  added to sorafenib
#  added to sorafenib
#  added to sorafenib
#  added to estradiol
#  added to diclofenac
#  added to estradiol
#  added to diclofenac
#  added to estradiol
#  added to diclofenac
#  added to bleomycin
#  added to bleomycin
#  added to bleomycin
#  added to bleomycin
#  added to bleomycin
#  added to bleomycin
#  added to estradiol
#  added to estradiol
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to pentoxifylline
#  added to orlistat
# human  added to chorionic gonadotropin
# Checking Biomarker: 28262537::span:375:381
# Checking Condition: 28262537::span:116:143
# 0
# Couldn't find: 28262537::span:116:143
# ADDING NEW CANDIDATE
# human  added to chorionic gonadotropin
# Checking Biomarker: 28262537::span:482:484
# Checking Condition: 28262537::span:116:143
# 1
# human  added to chorionic gonadotropin
# Checking Biomarker: 28262537::span:521:523
# Checking Condition: 28262537::span:116:143
# 1
# hip total  added to BMD
# Checking Biomarker: 28263001::span:1285:1287
# Checking Condition: 28263001::span:188:200
# 0
# Couldn't find: 28263001::span:188:200
# ADDING NEW CANDIDATE
#  added to SF
#  added to iron
#  added to SF
#  added to iron
#  added to iron
#  added to SF
#  added to iron
# prospective  added to paroxetine
# Checking Biomarker: 28262603::span:608:614
# Checking Condition: 28262603::span:221:242
# 0
# Couldn't find: 28262603::span:221:242
# ADDING NEW CANDIDATE
# prospective  added to paroxetine
# Checking Biomarker: 28262603::span:739:741
# Checking Condition: 28262603::span:221:242
# 1
#  added to SF
#  added to pentoxifylline
#  added to sorafenib
#  added to sorafenib
# plasma treatment  added to fibrinogen
# Checking Biomarker: 28261341::span:305:307
# Checking Condition: 28261341::span:107:133
# 0
# Couldn't find: 28261341::span:107:133
# ADDING NEW CANDIDATE
#  added to sorafenib
#  added to sorafenib
#  added to sorafenib
#  added to sorafenib
#  added to sorafenib
#  added to sorafenib
#  added to sorafenib
#  added to sorafenib
# hormone estrogenic  added to estradiol
# Checking Biomarker: 28263535::span:165:168
# Checking Condition: 28263535::span:102:129
# 0
# Couldn't find: 28263535::span:102:129
# ADDING NEW CANDIDATE
#  added to testosterone
#  added to estradiol
#  added to estradiol
#  added to pentoxifylline
#  added to pentoxifylline
#  added to iron
#  added to iron
# available  added to iron
# Checking Biomarker: 28262197::span:121:123
# Checking Condition: 28262197::span:131:144
# 0
# Couldn't find: 28262197::span:131:144
# ADDING NEW CANDIDATE
#  added to iron
#  added to iron
# available  added to iron
# Checking Biomarker: 28262197::span:110:119
# Checking Condition: 28262197::span:131:144
# 1
#  added to iron
#  added to iron
# available  added to iron
# Checking Biomarker: 28262197::span:125:128
# Checking Condition: 28262197::span:131:144
# 1
# plasma treatment  added to fibrinogen
# Checking Biomarker: 28261341::span:918:920
# Checking Condition: 28261341::span:112:138
# 0
# Couldn't find: 28261341::span:112:138
# ADDING NEW CANDIDATE
#  added to fibrinogen
#  added to colchicine
#  added to colchicine
#  added to colchicine
#  added to trimethoprim
#  added to streptomycin
#  added to piperacillin
#  added to chloramphenicol
#  added to trimethoprim
#  added to streptomycin
#  added to piperacillin
#  added to chloramphenicol
#  added to orlistat
#  added to orlistat
#  added to orlistat
#  added to cisplatin
#  added to Colchicine
#  added to cisplatin
#  added to irinotecan
#  added to pemetrexed
#  added to docetaxel
#  added to irinotecan
#  added to pemetrexed
#  added to docetaxel
#  added to irinotecan
#  added to pemetrexed
#  added to docetaxel
#  added to irinotecan
#  added to pemetrexed
#  added to docetaxel
#  added to ascorbic acid
#  added to ascorbic acid
#  added to ascorbic acid
#  added to estradiol
#  added to estradiol
#  added to tenofovir
#  added to tenofovir
#  added to tenofovir
# weight  added to heparin
# Checking Biomarker: 28262239::span:252:255
# Checking Condition: 28262239::span:23:36
# 0
# Couldn't find: 28262239::span:23:36
# ADDING NEW CANDIDATE
# weight  added to heparin
# Checking Biomarker: 28262239::span:338:340
# Checking Condition: 28262239::span:23:36
# 1
#  added to ascorbic acid
#  added to sorafenib
#  added to sorafenib
#  added to sorafenib
#  added to sorafenib
#  added to sorafenib
#  added to sorafenib
#  added to sorafenib
#  added to electrolyte
#  added to electrolyte
#  added to electrolyte
#  added to electrolyte
#  added to Vitamin D
#  added to Vitamin D
# mannosyl  added to tryptophan
# Checking Biomarker: 28262773::span:1205:1207
# Checking Condition: 28262773::span:21:39
# 0
# Couldn't find: 28262773::span:21:39
# ADDING NEW CANDIDATE
#  added to testosterone
#  added to orlistat
#  added to orlistat
#  added to orlistat
#  added to Orlistat
#  added to orlistat
#  added to orlistat
#  added to orlistat
#  added to Orlistat
#  added to Orlistat
#  added to Orlistat
# plasma treatment  added to fibrinogen
# Checking Biomarker: 28261341::span:1162:1163
# Checking Condition: 28261341::span:67:93
# 0
# Couldn't find: 28261341::span:67:93
# ADDING NEW CANDIDATE
# plasma treatment  added to fibrinogen
# Checking Biomarker: 28261341::span:1169:1172
# Checking Condition: 28261341::span:67:93
# 1
# plasma treatment  added to fibrinogen
# Checking Biomarker: 28261341::span:1446:1448
# Checking Condition: 28261341::span:41:67
# 0
# Couldn't find: 28261341::span:41:67
# ADDING NEW CANDIDATE
#  added to insulin
# Finished Processing Existing Candidates
# Number of dev BD candidates with adj. boosting:  270
# Number of dev BM candidates without adj. boosting:  396
#  added to blood
#  added to blood
#  added to bone marrow
#  added to bone marrow
#  added to blood
#  added to blood
#  added to blood
#  added to blood
# peripheral  added to blood
# Checking Biomarker: 28261204::span:526:529
# Checking Condition: 28261204::span:200:215
# 0
# Couldn't find: 28261204::span:200:215
# ADDING NEW CANDIDATE
# peripheral  added to blood
# Checking Biomarker: 28261204::span:703:706
# Checking Condition: 28261204::span:200:215
# 1
#  added to lymph
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
# cord  added to serum
# Checking Biomarker: 28262321::span:1253:1254
# Checking Condition: 28262321::span:223:232
# 0
# Couldn't find: 28262321::span:223:232
# ADDING NEW CANDIDATE
# maternal  added to serum
# Checking Biomarker: 28262321::span:1253:1254
# Checking Condition: 28262321::span:150:163
# 0
# Couldn't find: 28262321::span:150:163
# ADDING NEW CANDIDATE
# cord  added to serum
# Checking Biomarker: 28262321::span:1285:1287
# Checking Condition: 28262321::span:223:232
# 1
# maternal  added to serum
# Checking Biomarker: 28262321::span:1285:1287
# Checking Condition: 28262321::span:150:163
# 1
# cord  added to serum
# Checking Biomarker: 28262321::span:1263:1264
# Checking Condition: 28262321::span:223:232
# 1
# maternal  added to serum
# Checking Biomarker: 28262321::span:1263:1264
# Checking Condition: 28262321::span:150:163
# 1
# cord  added to serum
# Checking Biomarker: 28262321::span:1451:1453
# Checking Condition: 28262321::span:223:232
# 1
# maternal  added to serum
# Checking Biomarker: 28262321::span:1451:1453
# Checking Condition: 28262321::span:150:163
# 1
#  added to lymph
#  added to lymph
#  added to lymph
#  added to blood
#  added to blood
#  added to blood
#  added to blood
#  added to blood
#  added to plasma
#  added to serum
#  added to serum
#  added to serum
#  added to Blood
#  added to Blood
# maternal  added to serum
# Checking Biomarker: 28262321::span:1708:1710
# Checking Condition: 28262321::span:129:142
# 0
# Couldn't find: 28262321::span:129:142
# ADDING NEW CANDIDATE
# cord  added to serum
# Checking Biomarker: 28262321::span:1708:1710
# Checking Condition: 28262321::span:233:242
# 0
# Couldn't find: 28262321::span:233:242
# ADDING NEW CANDIDATE
# maternal  added to serum
# Checking Biomarker: 28262321::span:1767:1769
# Checking Condition: 28262321::span:129:142
# 1
# cord  added to serum
# Checking Biomarker: 28262321::span:1767:1769
# Checking Condition: 28262321::span:233:242
# 1
#  added to Serum
#  added to Serum
#  added to Serum
# baseline  added to serum
# Checking Biomarker: 28260649::span:901:906
# Checking Condition: 28260649::span:93:106
# 0
# Couldn't find: 28260649::span:93:106
# ADDING NEW CANDIDATE
# baseline  added to serum
# Checking Biomarker: 28260649::span:1280:1285
# Checking Condition: 28260649::span:153:166
# 0
# Couldn't find: 28260649::span:153:166
# ADDING NEW CANDIDATE
# baseline  added to serum
# Checking Biomarker: 28260649::span:1158:1160
# Checking Condition: 28260649::span:153:166
# 1
#  added to serum
#  added to serum
#  added to sera
#  added to sera
#  added to sera
#  added to serum
#  added to serum
#  added to serum
#  added to serum
#  added to serum
#  added to serum
#  added to serum
#  added to serum
#  added to serum
#  added to serum
#  added to blood
#  added to blood
#  added to cerebrospinal fluid
#  added to cerebrospinal fluid
#  added to cerebrospinal fluid
#  added to cerebrospinal fluid
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to cerebrospinal fluid
#  added to CSF
#  added to plasma
#  added to cerebrospinal fluid
#  added to serum
#  added to serum
#  added to serum
#  added to cerebrospinal fluid
#  added to CSF
#  added to CSF
#  added to cerebrospinal fluid
#  added to CSF
#  added to cerebrospinal fluid
#  added to CSF
#  added to cerebrospinal fluid
#  added to CSF
# procedural  added to serum
# Checking Biomarker: 28260767::span:932:932
# Checking Condition: 28260767::span:156:171
# 0
# Couldn't find: 28260767::span:156:171
# ADDING NEW CANDIDATE
# procedural  added to serum
# Checking Biomarker: 28260767::span:970:972
# Checking Condition: 28260767::span:156:171
# 1
#  added to CSF
#  added to CSF
#  added to CSF
#  added to CSF
#  added to CSF
#  added to CSF
#  added to CSF
#  added to CSF
#  added to CSF
#  added to serum
#  added to serum
#  added to CSF
#  added to serum
#  added to serum
#  added to serum
#  added to serum
#  added to serum
#  added to serum
#  added to urine
#  added to urine
#  added to urine
#  added to urine
#  added to Sera
#  added to Sera
#  added to cerebrospinal fluid
#  added to CSF
#  added to CSF
#  added to CSF
#  added to blood
#  added to plasma
#  added to blood
#  added to plasma
#  added to blood
#  added to plasma
#  added to plasma
#  added to Serum
#  added to CSF
#  added to CSF
# time first  added to serum
# Checking Biomarker: 28263100::span:413:415
# Checking Condition: 28263100::span:20:35
# 0
# Couldn't find: 28263100::span:20:35
# ADDING NEW CANDIDATE
# oxygenated  added to blood
# Checking Biomarker: 28264009::span:98:107
# Checking Condition: 28264009::span:105:120
# 0
# Couldn't find: 28264009::span:105:120
# ADDING NEW CANDIDATE
# available  added to serum
# Checking Biomarker: 28263100::span:910:912
# Checking Condition: 28263100::span:0:14
# 0
# Couldn't find: 28263100::span:0:14
# ADDING NEW CANDIDATE
# available  added to serum
# Checking Biomarker: 28263100::span:899:901
# Checking Condition: 28263100::span:0:14
# 1
#  added to blood
# tumor  added to blood
# Checking Biomarker: 28264009::span:753:755
# Checking Condition: 28264009::span:0:10
# 0
# Couldn't find: 28264009::span:0:10
# ADDING NEW CANDIDATE
# tumor  added to blood
# Checking Biomarker: 28264009::span:698:700
# Checking Condition: 28264009::span:0:10
# 1
#  added to serum
#  added to serum
#  added to serum
#  added to plasma
#  added to plasma
#  added to plasma
# retroperitoneal  added to lymph
# Checking Biomarker: 28262537::span:57:61
# Checking Condition: 28262537::span:15:35
# 0
# Couldn't find: 28262537::span:15:35
# ADDING NEW CANDIDATE
# retroperitoneal  added to lymph
# Checking Biomarker: 28262537::span:222:226
# Checking Condition: 28262537::span:27:47
# 0
# Couldn't find: 28262537::span:27:47
# ADDING NEW CANDIDATE
# retroperitoneal  added to lymph
# Checking Biomarker: 28262537::span:163:167
# Checking Condition: 28262537::span:27:47
# 1
# retroperitoneal  added to lymph
# Checking Biomarker: 28262537::span:94:103
# Checking Condition: 28262537::span:27:47
# 1
#  added to lymph
#  added to lymph
#  added to lymph
#  added to lymph
#  added to lymph
#  added to lymph
#  added to blood
#  added to cerebrospinal fluid
#  added to CSF
#  added to cerebrospinal fluid
#  added to CSF
#  added to CSF
#  added to CSF
#  added to CSF
#  added to CSF
#  added to CSF
#  added to CSF
#  added to CSF
#  added to CSF
#  added to CSF
# baseline  added to CSF
# Checking Biomarker: 28261960::span:1753:1755
# Checking Condition: 28261960::span:78:89
# 0
# Couldn't find: 28261960::span:78:89
# ADDING NEW CANDIDATE
# baseline  added to CSF
# Checking Biomarker: 28261960::span:1730:1732
# Checking Condition: 28261960::span:78:89
# 1
# baseline  added to CSF
# Checking Biomarker: 28261960::span:1659:1669
# Checking Condition: 28261960::span:78:89
# 1
#  added to Serum
#  added to Serum
#  added to Serum
#  added to Serum
# treatment  added to plasma
# Checking Biomarker: 28261341::span:305:307
# Checking Condition: 28261341::span:107:122
# 0
# Couldn't find: 28261341::span:107:122
# ADDING NEW CANDIDATE
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to serum
#  added to serum
#  added to serum
#  added to serum
#  added to serum
# maternal  added to plasma
# Checking Biomarker: 28263753::span:113:121
# Checking Condition: 28263753::span:4:18
# 0
# Couldn't find: 28263753::span:4:18
# ADDING NEW CANDIDATE
# maternal  added to plasma
# Checking Biomarker: 28263753::span:113:121
# Checking Condition: 28263753::span:186:200
# 0
# Couldn't find: 28263753::span:186:200
# ADDING NEW CANDIDATE
# treatment  added to plasma
# Checking Biomarker: 28261341::span:918:920
# Checking Condition: 28261341::span:112:127
# 0
# Couldn't find: 28261341::span:112:127
# ADDING NEW CANDIDATE
#  added to serum
#  added to serum
#  added to serum
#  added to serum
#  added to Serum
# cord  added to serum
# Checking Biomarker: 28262321::span:72:74
# Checking Condition: 28262321::span:101:110
# 0
# Couldn't find: 28262321::span:101:110
# ADDING NEW CANDIDATE
# cord  added to serum
# Checking Biomarker: 28262321::span:392:394
# Checking Condition: 28262321::span:101:110
# 1
#  added to serum
#  added to Serum
#  added to serum
#  added to Serum
#  added to serum
#  added to Serum
# cord umbilical  added to serum
# Checking Biomarker: 28262321::span:539:541
# Checking Condition: 28262321::span:117:136
# 0
# Couldn't find: 28262321::span:117:136
# ADDING NEW CANDIDATE
# cord umbilical  added to serum
# Checking Biomarker: 28262321::span:662:666
# Checking Condition: 28262321::span:117:136
# 1
#  added to cerebrospinal fluid
#  added to CSF
#  added to cerebrospinal fluid
#  added to CSF
#  added to cerebrospinal fluid
#  added to CSF
#  added to CSF
#  added to cerebrospinal fluid
#  added to CSF
#  added to CSF
#  added to cerebrospinal fluid
#  added to CSF
#  added to CSF
#  added to cerebrospinal fluid
#  added to CSF
#  added to urine
#  added to Urine
#  added to urine
#  added to Urine
#  added to urine
#  added to Urine
#  added to urine
#  added to Urine
#  added to urine
#  added to Urine
#  added to urine
#  added to Urine
#  added to plasma
#  added to plasma
#  added to serum
#  added to serum
#  added to serum
#  added to serum
#  added to serum
#  added to serum
#  added to lymph
#  added to lymph
#  added to Plasma
#  added to lymph
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to plasma
#  added to Plasma
#  added to Urine
# peripheral classical  added to lymph
# Checking Biomarker: 28260693::span:1238:1243
# Checking Condition: 28260693::span:35:60
# 0
# Couldn't find: 28260693::span:35:60
# ADDING NEW CANDIDATE
# peripheral classical  added to lymph
# Checking Biomarker: 28260693::span:1186:1186
# Checking Condition: 28260693::span:35:60
# 1
#  added to plasma
#  added to serum
#  added to serum
#  added to serum
#  added to Plasma
#  added to Plasma
#  added to Plasma
#  added to Plasma
#  added to Plasma
#  added to Plasma
#  added to Plasma
#  added to Plasma
#  added to Plasma
#  added to Plasma
#  added to cerebrospinal fluid
#  added to cerebrospinal fluid
#  added to serum
#  added to Plasma
#  added to plasma
#  added to astrocytes
#  added to blood
# potential  added to serum
# Checking Biomarker: 28260649::span:534:535
# Checking Condition: 28260649::span:45:59
# 0
# Couldn't find: 28260649::span:45:59
# ADDING NEW CANDIDATE
# potential  added to serum
# Checking Biomarker: 28260649::span:596:598
# Checking Condition: 28260649::span:45:59
# 1
#  added to CSF
# white  added to blood
# Checking Biomarker: 28264059::span:864:866
# Checking Condition: 28264059::span:33:43
# 0
# Couldn't find: 28264059::span:33:43
# ADDING NEW CANDIDATE
#  added to CSF
# white  added to blood
# Checking Biomarker: 28264059::span:1121:1122
# Checking Condition: 28264059::span:33:43
# 1
#  added to CSF
# white  added to blood
# Checking Biomarker: 28264059::span:1059:1061
# Checking Condition: 28264059::span:33:43
# 1
#  added to CSF
# white  added to blood
# Checking Biomarker: 28264059::span:964:965
# Checking Condition: 28264059::span:33:43
# 1
# white  added to blood
# Checking Biomarker: 28264059::span:1124:1126
# Checking Condition: 28264059::span:33:43
# 1
#  added to CSF
# white  added to blood
# Checking Biomarker: 28264059::span:885:887
# Checking Condition: 28264059::span:33:43
# 1
#  added to CSF
# white  added to blood
# Checking Biomarker: 28264059::span:838:840
# Checking Condition: 28264059::span:33:43
# 1
#  added to CSF
# white  added to blood
# Checking Biomarker: 28264059::span:967:969
# Checking Condition: 28264059::span:33:43
# 1
# fetal  added to serum
# Checking Biomarker: 28262321::span:1005:1007
# Checking Condition: 28262321::span:27:37
# 0
# Couldn't find: 28262321::span:27:37
# ADDING NEW CANDIDATE
# fetal  added to serum
# Checking Biomarker: 28262321::span:918:921
# Checking Condition: 28262321::span:27:37
# 1
# fetal  added to serum
# Checking Biomarker: 28262321::span:823:825
# Checking Condition: 28262321::span:27:37
# 1
#  added to plasma
#  added to plasma
#  added to plasma
#  added to urine
#  added to Urine
#  added to urine
#  added to Urine
#  added to urine
#  added to Urine
#  added to urine
#  added to Urine
#  added to urine
#  added to serum
#  added to serum
#  added to serum
#  added to serum
#  added to serum
#  added to serum
#  added to serum
#  added to sera
#  added to sera
#  added to Serum
#  added to serum
#  added to urine
#  added to urine
#  added to urine
#  added to serum
#  added to plasma
#  added to urine
#  added to urine
#  added to plasma
# novel  added to serum
# Checking Biomarker: 28262692::span:0:6
# Checking Condition: 28262692::span:16:26
# 0
# Couldn't find: 28262692::span:16:26
# ADDING NEW CANDIDATE
#  added to Urine
#  added to urine
#  added to serum
#  added to serum
#  added to serum
#  added to serum
# tumor  added to blood
# Checking Biomarker: 28264009::span:273:275
# Checking Condition: 28264009::span:72:82
# 0
# Couldn't find: 28264009::span:72:82
# ADDING NEW CANDIDATE
#  added to astrocytes
#  added to Serum
#  added to serum
#  added to serum
#  added to serum
#  added to astrocytes
#  added to lymph
#  added to serum
#  added to serum
#  added to serum
#  added to serum
#  added to serum
#  added to serum
# treatment  added to plasma
# Checking Biomarker: 28261341::span:1162:1163
# Checking Condition: 28261341::span:67:82
# 0
# Couldn't find: 28261341::span:67:82
# ADDING NEW CANDIDATE
# treatment  added to plasma
# Checking Biomarker: 28261341::span:1169:1172
# Checking Condition: 28261341::span:67:82
# 1
# treatment  added to plasma
# Checking Biomarker: 28261341::span:1446:1448
# Checking Condition: 28261341::span:41:56
# 0
# Couldn't find: 28261341::span:41:56
# ADDING NEW CANDIDATE
#  added to blood
#  added to Blood
#  added to Blood
#  added to blood
#  added to blood
#  added to blood
#  added to blood
#  added to blood
# dead  added to astrocytes
# Checking Biomarker: 28264063::span:1257:1259
# Checking Condition: 28264063::span:154:168
# 0
# Couldn't find: 28264063::span:154:168
# ADDING NEW CANDIDATE
# dead  added to astrocytes
# Checking Biomarker: 28264063::span:1257:1259
# Checking Condition: 28264063::span:32:46
# 0
# Couldn't find: 28264063::span:32:46
# ADDING NEW CANDIDATE
#  added to bone marrow
# human  added to plasma
# Checking Biomarker: 28262555::span:549:551
# Checking Condition: 28262555::span:29:40
# 0
# Couldn't find: 28262555::span:29:40
# ADDING NEW CANDIDATE
# marrow bone  added to plasma
# Checking Biomarker: 28262555::span:549:551
# Checking Condition: 28262555::span:159:176
# 0
# Couldn't find: 28262555::span:159:176
# ADDING NEW CANDIDATE
# Finished Processing Existing Candidates
# Number of dev BM candidates with adj. boosting:  396

# %%
#-------------------------------------------
# External Gold Labels & Labeling Functions
#-------------------------------------------
from LF import *
# Labeling Functions
LFs_BC = [LF_markerDatabase, LF_keyword, LF_distance, LF_abstract_titleWord, LF_single_letter,
          LF_auxpass, LF_known_abs, LF_same_thing_BC, LF_common_1000, LF_common_2000]
LFs_BD = [LF_colon, LF_known_abs, LF_single_letter,
          LF_roman_numeral, LF_common_2000, LF_same_thing_BD]
LFs_BM = [LF_distance_far, LF_colon, LF_known_abs, LF_single_letter, LF_roman_numeral, LF_common_2000, LF_same_thing]
LFs_BT = [LF_colon, LF_known_abs, LF_single_letter, LF_roman_numeral, LF_common_2000, LF_same_thing]

labeler_BC = LabelAnnotator(lfs=LFs_BC)
labeler_BD = LabelAnnotator(lfs=LFs_BD)
labeler_BM = LabelAnnotator(lfs=LFs_BM)
labeler_BT = LabelAnnotator(lfs=LFs_BT)

# Training
L_train_BC = labeler_BC.apply(split=0)
L_train_BD = labeler_BD.apply(split=0)
L_train_BM = labeler_BM.apply(split=0)
L_train_BT = labeler_BT.apply(split=0)
L_train_BC
L_train_BD
L_train_BM
L_train_BT

# Labeling Function Performance - Coverage, Overlaps, Conflicts
L_train_BC.lf_stats(session)
L_train_BD.lf_stats(session)
L_train_BM.lf_stats(session)
L_train_BT.lf_stats(session)
# Out:
# Clearing existing...
# Running UDF...
# [==========================              ] 63%

# %%
tp, fp, tn, fn = L_train_BC.error_analysis(session, L_dev, L_gold_dev)
